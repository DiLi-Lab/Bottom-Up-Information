# %%
# Import
import numpy as np
import math
from PIL import Image, ImageDraw, ImageFont
import os
import json

# test perceptual similarity metrics on letters
from skimage.metrics import structural_similarity as ssim
import numpy as np
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt

# %%
def entropy(freqs):
    total = sum(freqs)
    if total == 0:
        return 0
    return -sum((f / total) * np.log(f / total) for f in freqs if f > 0)

# %% [markdown]
# ## Baseline -- English conditional entropy
#
# ### As a sanity check, if threshold set to 0, i.e., score > 0.0, calculate the marginal prob etc., the conditional entropy should be the same as, or very similar to the unconditional entropy.

# %%
## note, this is the innitial version, which used the row ssim metric, not the scaled ssim metric
## the scaled ssim metric is more distinguishing between similar and dissimilar images

visible = "upper"
lang = "en"
threshold = 0.2

if lang == "en":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/EN"
if lang == "zh":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/ZH"
# img_path = f"/swdata/yin/Cui/Re-Veil/create-dataset-new/dataset_en/en_word_{visible}_20250513/images"
# jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/en/en-word/{visible}/img_dict_test.json"

conditional_prob_ent_dict = {}

# pick a fixed size for all images (e.g., 28x28)
resize_shape = (128, 128)

with open(jsonl_file_path, 'r') as file:
    lines = file.readlines()
    print("total lines:", len(lines))

comparison_counter = 0  # keep track of comparisons
sum_freq = 0.0

for line in lines:
    p_marginal = 0
    p_similars = []
    data = json.loads(line)
    img = img_path + "/" + data["image"]
    target = data["label"]
    p_target = data["normal_freq"]

    img_target = np.array(Image.open(img).convert("L").resize(resize_shape))
    sum_freq += p_target   ## accumulate total frequency sum should be 1.0

    # compare img_target with all other images
    for comp_line in lines:
        comp_data = json.loads(comp_line)
        comp_img_path = img_path + "/" + comp_data["image"]
        comparison = comp_data["label"]
        p_comp = comp_data["normal_freq"]

        img_comp = np.array(Image.open(comp_img_path).convert("L").resize(resize_shape))

        similarity = ssim(img_target, img_comp)
        if similarity > threshold:  # threshold for considering similar
            p_similars.append(p_comp)
            p_marginal += p_comp

        # # Show the two images every 400th comparison for visual inspection
        # comparison_counter += 1
        # if comparison_counter % 400 == 0:
        #     print(f"[{comparison_counter}] {img} vs {comp_img_path}, SSIM = {similarity:.3f}")
        #     fig, axes = plt.subplots(1, 2, figsize=(4, 2))
        #     axes[0].imshow(img_target, cmap="gray")
        #     axes[0].set_title(f"Target: {target}")
        #     axes[0].axis("off")
        #     axes[1].imshow(img_comp, cmap="gray")
        #     axes[1].set_title(f"Comp: {comparison}")
        #     axes[1].axis("off")
        #     plt.show()

    p_target_given_orth = p_target / p_marginal if p_marginal > 0 else 0
    ent_cond = entropy(p_similars) if len(p_similars) > 0 else 0
    conditional_prob_ent_dict[target] = (p_target_given_orth, ent_cond, p_target, p_marginal)  
    print(f"{target}|orthographic representations --> prob = {p_target_given_orth}, entropy = {ent_cond}, freq = {p_target}, marginal prob = {p_marginal}") 

# compute overall conditional entropy
H_W_given_O = 0.0
rows = []
for word, (p_target_given_orth, ent_cond, freq_target, p_marginal) in conditional_prob_ent_dict.items():
    H_W_given_O += freq_target * ent_cond
    rows.append({
        "target": word,
        "prob_target": p_target_given_orth,
        "entropy": ent_cond,
        "freq": freq_target,
        "marginal": p_marginal
    })

print(f"Overall conditional entropy H(L|O) = {H_W_given_O:.4f} nats")
print(f"Sum of frequencies (should be ~1.0) = {sum_freq:.4f}")

# df = pd.DataFrame(rows, columns=["target", "prob_target", "entropy", "freq", "marginal"])
# out_csv = f"{out_path}/baseline_{lang}_word_{visible}_{threshold}.csv"
# df.to_csv(out_csv, index=False)
# print(f"Results saved to {out_csv}")
# Out:
# total lines: 692
# Year|orthographic representations --> prob = 0.0012620344886189255, entropy = 4.665206077661126, freq = 0.0012620344886189, marginal prob = 0.9999999999999799
# Old|orthographic representations --> prob = 0.0007780594319694201, entropy = 4.663097475696409, freq = 0.0007777010774164, marginal prob = 0.9995394252183114
# Bottle|orthographic representations --> prob = 5.176569070873968e-05, entropy = 4.65327268977921, freq = 5.147772256208681e-05, marginal prob = 0.9944370848198835
# Message|orthographic representations --> prob = 0.0001383809746292028, entropy = 4.665206077661126, freq = 0.0001383809746292, marginal prob = 0.9999999999999799
# Angela|orthographic representations --> prob = 1.453000233607318e-05, entropy = 4.665206077661126, freq = 1.4530002336072889e-05, marginal prob = 0.9999999999999799
# Erdmann|orthographic representations --> prob = 1.8266288651063427e-07, entropy = 4.665206077661126, freq = 1.826628865106306e-07, marginal prob = 0.9999999999999799
# never|orthographic representations --> prob = 0.0011250373237359226, entropy = 4.665206077661126, freq = 0.0011250373237359, marginal prob = 0.9999999999999799
# knew|orthographic representations --> prob = 0.00021864193991420438, entropy = 4.665206077661126, freq = 0.0002186419399142, marginal prob = 0.9999999999999799
# her|orthographic representations --> prob = 0.0027676194925853556, entropy = 4.665206077661126, freq = 0.0027676194925853, marginal prob = 0.9999999999999799
# grandfather|orthographic representations --> prob = 2.4078289585492696e-05, entropy = 4.665206077661126, freq = 2.4078289585492212e-05, marginal prob = 0.9999999999999799
# He|orthographic representations --> prob = 0.006780667756834136, entropy = 4.665206077661126, freq = 0.006780667756834, marginal prob = 0.9999999999999799
# died|orthographic representations --> prob = 0.00021893733333951435, entropy = 4.660460275899931, freq = 0.0002186419399142, marginal prob = 0.9986507854973447
# in|orthographic representations --> prob = 0.025738861281043916, entropy = 4.665206077661126, freq = 0.0257388612810434, marginal prob = 0.9999999999999799
# six|orthographic representations --> prob = 0.0002698429005270054, entropy = 4.665206077661126, freq = 0.000269842900527, marginal prob = 0.9999999999999799
# years|orthographic representations --> prob = 0.0012620344886189255, entropy = 4.665206077661126, freq = 0.0012620344886189, marginal prob = 0.9999999999999799
# before|orthographic representations --> prob = 0.0011776220940950236, entropy = 4.665206077661126, freq = 0.001177622094095, marginal prob = 0.9999999999999799
# she|orthographic representations --> prob = 0.0025185337382526507, entropy = 4.665206077661126, freq = 0.0025185337382526, marginal prob = 0.9999999999999799
# was|orthographic representations --> prob = 0.009146982422994583, entropy = 4.665206077661126, freq = 0.0091469824229944, marginal prob = 0.9999999999999799
# born|orthographic representations --> prob = 0.0001702085987939034, entropy = 4.665206077661126, freq = 0.0001702085987939, marginal prob = 0.9999999999999799
# But|orthographic representations --> prob = 0.0059101753681381685, entropy = 4.663940991761107, freq = 0.0059088676166696, marginal prob = 0.9997787288215475
# on|orthographic representations --> prob = 0.011250373237359425, entropy = 4.665206077661126, freq = 0.0112503732373592, marginal prob = 0.9999999999999799
# Tuesday|orthographic representations --> prob = 5.90886761666976e-05, entropy = 4.665206077661126, freq = 5.908867616669641e-05, marginal prob = 0.9999999999999799
# April|orthographic representations --> prob = 0.00021453875380830688, entropy = 4.664083661562985, freq = 0.0002144905106753, marginal prob = 0.9997751309162074
# described|orthographic representations --> prob = 0.0001383809746292028, entropy = 4.665206077661126, freq = 0.0001383809746292, marginal prob = 0.9999999999999799
# the|orthographic representations --> prob = 0.0743105833759171, entropy = 4.665206077661126, freq = 0.0743105833759156, marginal prob = 0.9999999999999799
# extraordinary|orthographic representations --> prob = 3.168924319010246e-05, entropy = 4.665206077661126, freq = 3.1689243190101826e-05, marginal prob = 0.9999999999999799
# moment|orthographic representations --> prob = 0.00024078289585490484, entropy = 4.665206077661126, freq = 0.0002407828958549, marginal prob = 0.9999999999999799
# when|orthographic representations --> prob = 0.0032381148063248652, entropy = 4.665206077661126, freq = 0.0032381148063248, marginal prob = 0.9999999999999799
# received|orthographic representations --> prob = 0.00020065241321240405, entropy = 4.665206077661126, freq = 0.0002006524132124, marginal prob = 0.9999999999999799
# a|orthographic representations --> prob = 0.03168924319010244, entropy = 4.665206077661126, freq = 0.0316892431901018, marginal prob = 0.9999999999999799
# message|orthographic representations --> prob = 0.0001383809746292028, entropy = 4.665206077661126, freq = 0.0001383809746292, marginal prob = 0.9999999999999799
# bottle|orthographic representations --> prob = 5.147772256208785e-05, entropy = 4.665206077661126, freq = 5.147772256208681e-05, marginal prob = 0.9999999999999799
# after|orthographic representations --> prob = 0.0017851145727175357, entropy = 4.665206077661126, freq = 0.0017851145727175, marginal prob = 0.9999999999999799
# he|orthographic representations --> prob = 0.006780667756834136, entropy = 4.665206077661126, freq = 0.006780667756834, marginal prob = 0.9999999999999799
# had|orthographic representations --> prob = 0.0029613528570662595, entropy = 4.665206077661126, freq = 0.0029613528570662, marginal prob = 0.9999999999999799
# lobbed|orthographic representations --> prob = 3.3961986250093263e-07, entropy = 4.660261911496396, freq = 3.390333878417007e-07, marginal prob = 0.9982731438175813
# it|orthographic representations --> prob = 0.012329744839467749, entropy = 4.665206077661126, freq = 0.0123297448394675, marginal prob = 0.9999999999999799
# into|orthographic representations --> prob = 0.0017851145727175357, entropy = 4.665206077661126, freq = 0.0017851145727175, marginal prob = 0.9999999999999799
# Baltic|orthographic representations --> prob = 5.167939330584014e-06, entropy = 4.657844776826948, freq = 5.14777225620868e-06, marginal prob = 0.9960976565154346
# Sea|orthographic representations --> prob = 0.0001591381208236032, entropy = 4.665206077661126, freq = 0.0001591381208236, marginal prob = 0.9999999999999799
# Thought|orthographic representations --> prob = 0.0005383981909583511, entropy = 4.664273231662198, freq = 0.0005383019913078, marginal prob = 0.9998213224855385
# to|orthographic representations --> prob = 0.037224482175273146, entropy = 4.665206077661126, freq = 0.0372244821752724, marginal prob = 0.9999999999999799
# be|orthographic representations --> prob = 0.008538106134625773, entropy = 4.665206077661126, freq = 0.0085381061346256, marginal prob = 0.9999999999999799
# world|orthographic representations --> prob = 0.0010738363631231217, entropy = 4.665206077661126, freq = 0.0010738363631231, marginal prob = 0.9999999999999799
# s|orthographic representations --> prob = 0.0010018782563158202, entropy = 4.665206077661126, freq = 0.0010018782563158, marginal prob = 0.9999999999999799
# oldest|orthographic representations --> prob = 2.4078289585492696e-05, entropy = 4.665206077661126, freq = 2.4078289585492212e-05, marginal prob = 0.9999999999999799
# presented|orthographic representations --> prob = 7.777010774164882e-05, entropy = 4.665206077661126, freq = 7.777010774164726e-05, marginal prob = 0.9999999999999799
# by|orthographic representations --> prob = 0.006324010540557527, entropy = 4.665206077661126, freq = 0.0063240105405574, marginal prob = 0.9999999999999799
# museum|orthographic representations --> prob = 7.098943998481468e-05, entropy = 4.665206077661126, freq = 7.098943998481325e-05, marginal prob = 0.9999999999999799
# that|orthographic representations --> prob = 0.014114859412185285, entropy = 4.665206077661126, freq = 0.014114859412185, marginal prob = 0.9999999999999799
# is|orthographic representations --> prob = 0.016190574031624327, entropy = 4.665206077661126, freq = 0.016190574031624, marginal prob = 0.9999999999999799
# now|orthographic representations --> prob = 0.002089552716901942, entropy = 4.665206077661126, freq = 0.0020895527169019, marginal prob = 0.9999999999999799
# exhibiting|orthographic representations --> prob = 3.4733624631946367e-06, entropy = 4.665206077661126, freq = 3.473362463194567e-06, marginal prob = 0.9999999999999799
# Germany|orthographic representations --> prob = 0.0001098744938556022, entropy = 4.665206077661126, freq = 0.0001098744938556, marginal prob = 0.9999999999999799
# It|orthographic representations --> prob = 0.012329744839467749, entropy = 4.665206077661126, freq = 0.0123297448394675, marginal prob = 0.9999999999999799
# very|orthographic representations --> prob = 0.0013838097462926277, entropy = 4.665206077661126, freq = 0.0013838097462926, marginal prob = 0.9999999999999799
# surprising|orthographic representations --> prob = 2.643076615419026e-05, entropy = 4.665206077661126, freq = 2.643076615418973e-05, marginal prob = 0.9999999999999799
# said|orthographic representations --> prob = 0.0014116109588827122, entropy = 4.664662472943239, freq = 0.0014114859412185, marginal prob = 0.9999114361762172
# recalling|orthographic representations --> prob = 3.3211433911024412e-06, entropy = 4.665206077661126, freq = 3.3211433911023743e-06, marginal prob = 0.9999999999999799
# how|orthographic representations --> prob = 0.0024080818821820916, entropy = 4.664628766307434, freq = 0.0024078289585492, marginal prob = 0.9998949688402362
# found|orthographic representations --> prob = 0.0006628448684741134, entropy = 4.665206077661126, freq = 0.0006628448684741, marginal prob = 0.9999999999999799
# out|orthographic representations --> prob = 0.003321143391102367, entropy = 4.665206077661126, freq = 0.0033211433911023, marginal prob = 0.9999999999999799
# about|orthographic representations --> prob = 0.0034733624631945697, entropy = 4.665206077661126, freq = 0.0034733624631945, marginal prob = 0.9999999999999799
# A|orthographic representations --> prob = 0.03168924319010244, entropy = 4.665206077661126, freq = 0.0316892431901018, marginal prob = 0.9999999999999799
# man|orthographic representations --> prob = 0.0009146982422994184, entropy = 4.665206077661126, freq = 0.0009146982422994, marginal prob = 0.9999999999999799
# stood|orthographic representations --> prob = 5.147772256208785e-05, entropy = 4.665206077661126, freq = 5.147772256208681e-05, marginal prob = 0.9999999999999799
# at|orthographic representations --> prob = 0.00693288682892634, entropy = 4.665206077661126, freq = 0.0069328868289262, marginal prob = 0.9999999999999799
# my|orthographic representations --> prob = 0.005147772256208703, entropy = 4.665206077661126, freq = 0.0051477722562086, marginal prob = 0.9999999999999799
# door|orthographic representations --> prob = 0.00016605716955510333, entropy = 4.665206077661126, freq = 0.0001660571695551, marginal prob = 0.9999999999999799
# and|orthographic representations --> prob = 0.03556391047972191, entropy = 4.665206077661126, freq = 0.0355639104797212, marginal prob = 0.9999999999999799
# told|orthographic representations --> prob = 0.00048091469133865737, entropy = 4.659616312553997, freq = 0.0004801819819635, marginal prob = 0.9984764254693117
# me|orthographic representations --> prob = 0.004179105433803884, entropy = 4.665206077661126, freq = 0.0041791054338038, marginal prob = 0.9999999999999799
# post|orthographic representations --> prob = 0.0003722448217527075, entropy = 4.665206077661126, freq = 0.0003722448217527, marginal prob = 0.9999999999999799
# from|orthographic representations --> prob = 0.005908867616669719, entropy = 4.665206077661126, freq = 0.0059088676166696, marginal prob = 0.9999999999999799
# then|orthographic representations --> prob = 0.0016190574031624326, entropy = 4.665206077661126, freq = 0.0016190574031624, marginal prob = 0.9999999999999799
# been|orthographic representations --> prob = 0.0025738861281043514, entropy = 4.665206077661126, freq = 0.0025738861281043, marginal prob = 0.9999999999999799
# name|orthographic representations --> prob = 0.0005632105667411113, entropy = 4.665206077661126, freq = 0.0005632105667411, marginal prob = 0.9999999999999799
# card|orthographic representations --> prob = 0.00015221907209210305, entropy = 4.665206077661126, freq = 0.0001522190720921, marginal prob = 0.9999999999999799
# of|orthographic representations --> prob = 0.0347336246319463, entropy = 4.665206077661126, freq = 0.0347336246319456, marginal prob = 0.9999999999999799
# Her|orthographic representations --> prob = 0.002767663536662785, entropy = 4.66508858238042, freq = 0.0027676194925853, marginal prob = 0.9999840861878976
# visitor|orthographic representations --> prob = 1.4119490081238319e-05, entropy = 4.663552385262028, freq = 1.4114859412185093e-05, marginal prob = 0.9996720370901085
# genealogical|orthographic representations --> prob = 1.5221907209219522e-06, entropy = 4.665206077661126, freq = 1.5221907209219217e-06, marginal prob = 0.9999999999999799
# researcher|orthographic representations --> prob = 1.1513297089155133e-05, entropy = 4.665206077661126, freq = 1.15132970891549e-05, marginal prob = 0.9999999999999799
# who|orthographic representations --> prob = 0.0030305433443809605, entropy = 4.665206077661126, freq = 0.0030305433443809, marginal prob = 0.9999999999999799
# managed|orthographic representations --> prob = 7.956906041182933e-05, entropy = 4.665206077661126, freq = 7.956906041182773e-05, marginal prob = 0.9999999999999799
# track|orthographic representations --> prob = 0.00014530002336070292, entropy = 4.665206077661126, freq = 0.0001453000233607, marginal prob = 0.9999999999999799
# down|orthographic representations --> prob = 0.001050311597436121, entropy = 4.665206077661126, freq = 0.0010503115974361, marginal prob = 0.9999999999999799
# Berlin|orthographic representations --> prob = 3.321143391102441e-05, entropy = 4.665206077661126, freq = 3.321143391102375e-05, marginal prob = 0.9999999999999799
# letter|orthographic representations --> prob = 0.0001240303271783516, entropy = 4.65650921969691, freq = 0.0001232974483946, marginal prob = 0.9940911323833103
# given|orthographic representations --> prob = 0.0003558099583281995, entropy = 4.663296005325792, freq = 0.0003556391047972, marginal prob = 0.9995198180180164
# International|orthographic representations --> prob = 0.0003168924319010063, entropy = 4.665206077661126, freq = 0.000316892431901, marginal prob = 0.9999999999999799
# Maritime|orthographic representations --> prob = 1.2627142101927274e-05, entropy = 4.663126242738288, freq = 1.2620344886189024e-05, marginal prob = 0.999461698008672
# Museum|orthographic representations --> prob = 7.098943998481468e-05, entropy = 4.665206077661126, freq = 7.098943998481325e-05, marginal prob = 0.9999999999999799
# northern|orthographic representations --> prob = 9.7973730037522e-05, entropy = 4.665206077661126, freq = 9.797373003752004e-05, marginal prob = 0.9999999999999799
# port|orthographic representations --> prob = 7.431058337591712e-05, entropy = 4.665206077661126, freq = 7.431058337591563e-05, marginal prob = 0.9999999999999799
# city|orthographic representations --> prob = 0.0005632105667411113, entropy = 4.665206077661126, freq = 0.0005632105667411, marginal prob = 0.9999999999999799
# Hamburg|orthographic representations --> prob = 5.770486642040492e-06, entropy = 4.665206077661126, freq = 5.770486642040376e-06, marginal prob = 0.9999999999999799
# The|orthographic representations --> prob = 0.07434898174932682, entropy = 4.662797311218055, freq = 0.0743105833759156, marginal prob = 0.9994835386778977
# brown|orthographic representations --> prob = 0.00014114859412180285, entropy = 4.665206077661126, freq = 0.0001411485941218, marginal prob = 0.9999999999999799
# beer|orthographic representations --> prob = 6.932886828926346e-05, entropy = 4.665206077661126, freq = 6.932886828926206e-05, marginal prob = 0.9999999999999799
# which|orthographic representations --> prob = 0.002768249647808998, entropy = 4.6639834804810185, freq = 0.0027676194925853, marginal prob = 0.9997723632967147
# water|orthographic representations --> prob = 0.0004580410260228092, entropy = 4.665206077661126, freq = 0.0004580410260228, marginal prob = 0.9999999999999799
# for|orthographic representations --> prob = 0.014114859412185285, entropy = 4.665206077661126, freq = 0.014114859412185, marginal prob = 0.9999999999999799
# catch|orthographic representations --> prob = 0.00010254030220020205, entropy = 4.665206077661126, freq = 0.0001025403022002, marginal prob = 0.9999999999999799
# Konrad|orthographic representations --> prob = 9.797373003752203e-07, entropy = 4.665206077661126, freq = 9.797373003752006e-07, marginal prob = 0.9999999999999799
# Fischer|orthographic representations --> prob = 4.580410260228784e-06, entropy = 4.665206077661126, freq = 4.580410260228692e-06, marginal prob = 0.9999999999999799
# fisherman|orthographic representations --> prob = 4.275972116044393e-06, entropy = 4.665206077661126, freq = 4.275972116044308e-06, marginal prob = 0.9999999999999799
# off|orthographic representations --> prob = 0.0011776220940950236, entropy = 4.665206077661126, freq = 0.001177622094095, marginal prob = 0.9999999999999799
# Kiel|orthographic representations --> prob = 9.161561960536731e-07, entropy = 4.659344953970246, freq = 9.146982422994456e-07, marginal prob = 0.9984086187917436
# Holger|orthographic representations --> prob = 5.515861281952868e-07, entropy = 4.6601460718820045, freq = 5.507562790244771e-07, marginal prob = 0.9984955220438104
# von|orthographic representations --> prob = 2.0480384245131722e-05, entropy = 4.665206077661126, freq = 2.0480384245131312e-05, marginal prob = 0.9999999999999799
# Neuhoff|orthographic representations --> prob = 2.541654762016803e-08, entropy = 4.7531397262862365, freq = 2.3524765686975155e-08, marginal prob = 0.9255688867951622
# curator|orthographic representations --> prob = 4.912524599339028e-06, entropy = 4.665206077661126, freq = 4.912524599338929e-06, marginal prob = 0.9999999999999799
# ocean|orthographic representations --> prob = 6.932886828926346e-05, entropy = 4.665206077661126, freq = 6.932886828926206e-05, marginal prob = 0.9999999999999799
# science|orthographic representations --> prob = 0.00018266288651060366, entropy = 4.665206077661126, freq = 0.0001826628865106, marginal prob = 0.9999999999999799
# this|orthographic representations --> prob = 0.009146982422994583, entropy = 4.665206077661126, freq = 0.0091469824229944, marginal prob = 0.9999999999999799
# bottled|orthographic representations --> prob = 4.283368878072988e-06, entropy = 4.660261911496396, freq = 4.275972116044308e-06, marginal prob = 0.9982731438175813
# come|orthographic representations --> prob = 0.0008344372770144168, entropy = 4.665206077661126, freq = 0.0008344372770144, marginal prob = 0.9999999999999799
# across|orthographic representations --> prob = 0.0002463181348400049, entropy = 4.665206077661126, freq = 0.00024631813484, marginal prob = 0.9999999999999799
# There|orthographic representations --> prob = 0.0028229718824370567, entropy = 4.665206077661126, freq = 0.002822971882437, marginal prob = 0.9999999999999799
# are|orthographic representations --> prob = 0.007610953604609753, entropy = 4.665206077661126, freq = 0.0076109536046096, marginal prob = 0.9999999999999799
# documents|orthographic representations --> prob = 6.0472485912990285e-05, entropy = 4.665206077661126, freq = 6.047248591298907e-05, marginal prob = 0.9999999999999799
# have|orthographic representations --> prob = 0.007098943998481442, entropy = 4.665206077661126, freq = 0.0070989439984813, marginal prob = 0.9999999999999799
# without|orthographic representations --> prob = 0.0006780667756834136, entropy = 4.665206077661126, freq = 0.0006780667756834, marginal prob = 0.9999999999999799
# older|orthographic representations --> prob = 0.00011515496154452277, entropy = 4.664270526837262, freq = 0.0001151329708915, marginal prob = 0.9998090342549916
# with|orthographic representations --> prob = 0.00980827738310731, entropy = 4.661356734748383, freq = 0.009797373003752, marginal prob = 0.9988882472498085
# document|orthographic representations --> prob = 4.3728387982848816e-05, entropy = 4.665206077661126, freq = 4.3728387982847935e-05, marginal prob = 0.9999999999999799
# certainly|orthographic representations --> prob = 0.0001383809746292028, entropy = 4.665206077661126, freq = 0.0001383809746292, marginal prob = 0.9999999999999799
# extremely|orthographic representations --> prob = 8.53810613462586e-05, entropy = 4.665206077661126, freq = 8.538106134625688e-05, marginal prob = 0.9999999999999799
# good|orthographic representations --> prob = 0.0018275496671034271, entropy = 4.6629455785295475, freq = 0.0018266288651063, marginal prob = 0.9994961548713549
# condition|orthographic representations --> prob = 0.00010018782563150202, entropy = 4.665206077661126, freq = 0.0001001878256315, marginal prob = 0.9999999999999799
# Researchers|orthographic representations --> prob = 3.390333878417076e-05, entropy = 4.665206077661126, freq = 3.3903338784170074e-05, marginal prob = 0.9999999999999799
# believe|orthographic representations --> prob = 0.000448354357798809, entropy = 4.665206077661126, freq = 0.0004483543577988, marginal prob = 0.9999999999999799
# Richard|orthographic representations --> prob = 8.53810613462586e-05, entropy = 4.665206077661126, freq = 8.538106134625688e-05, marginal prob = 0.9999999999999799
# Platz|orthographic representations --> prob = 3.3903338784170754e-07, entropy = 4.665206077661126, freq = 3.390333878417007e-07, marginal prob = 0.9999999999999799
# threw|orthographic representations --> prob = 3.985372069322929e-05, entropy = 4.665206077661126, freq = 3.985372069322849e-05, marginal prob = 0.9999999999999799
# sea|orthographic representations --> prob = 0.0001591381208236032, entropy = 4.665206077661126, freq = 0.0001591381208236, marginal prob = 0.9999999999999799
# while|orthographic representations --> prob = 0.0010018782563158202, entropy = 4.665206077661126, freq = 0.0010018782563158, marginal prob = 0.9999999999999799
# hike|orthographic representations --> prob = 1.233680573264354e-05, entropy = 4.66249001159164, freq = 1.2329744839467564e-05, marginal prob = 0.9994276562889134
# nature|orthographic representations --> prob = 0.00013215383077090265, entropy = 4.665206077661126, freq = 0.0001321538307709, marginal prob = 0.9999999999999799
# appreciation|orthographic representations --> prob = 1.8266288651063427e-05, entropy = 4.665206077661126, freq = 1.826628865106306e-05, marginal prob = 0.9999999999999799
# group|orthographic representations --> prob = 0.0005147772256208103, entropy = 4.665206077661126, freq = 0.0005147772256208, marginal prob = 0.9999999999999799
# old|orthographic representations --> prob = 0.0007777010774164156, entropy = 4.665206077661126, freq = 0.0007777010774164, marginal prob = 0.9999999999999799
# time|orthographic representations --> prob = 0.002698429005270654, entropy = 4.665206077661126, freq = 0.0026984290052706, marginal prob = 0.9999999999999799
# Much|orthographic representations --> prob = 0.00138923222065269, entropy = 4.657835757113217, freq = 0.0013838097462926, marginal prob = 0.9960967833314848
# postcard|orthographic representations --> prob = 3.8054768023048808e-06, entropy = 4.665206077661126, freq = 3.805476802304804e-06, marginal prob = 0.9999999999999799
# indecipherable|orthographic representations --> prob = 2.4078289585492696e-07, entropy = 4.665206077661126, freq = 2.4078289585492214e-07, marginal prob = 0.9999999999999799
# although|orthographic representations --> prob = 0.0002767619492585056, entropy = 4.665206077661126, freq = 0.0002767619492585, marginal prob = 0.9999999999999799
# address|orthographic representations --> prob = 0.00011250373237350226, entropy = 4.665206077661126, freq = 0.0001125037323735, marginal prob = 0.9999999999999799
# front|orthographic representations --> prob = 0.0002643076615418053, entropy = 4.665206077661126, freq = 0.0002643076615418, marginal prob = 0.9999999999999799
# legible|orthographic representations --> prob = 8.751992356731847e-07, entropy = 4.657702598720544, freq = 8.731839499106659e-07, marginal prob = 0.9976973405821491
# as|orthographic representations --> prob = 0.008150639405663863, entropy = 4.665206077661126, freq = 0.0081506394056637, marginal prob = 0.9999999999999799
# author|orthographic representations --> prob = 0.0001233008608932631, entropy = 4.665017051823293, freq = 0.0001232974483946, marginal prob = 0.9999723238050541
# polite|orthographic representations --> prob = 1.1513297089155133e-05, entropy = 4.665206077661126, freq = 1.15132970891549e-05, marginal prob = 0.9999999999999799
# request|orthographic representations --> prob = 7.956906041182933e-05, entropy = 4.665206077661126, freq = 7.956906041182773e-05, marginal prob = 0.9999999999999799
# note|orthographic representations --> prob = 0.00015221907209210305, entropy = 4.665206077661126, freq = 0.0001522190720921, marginal prob = 0.9999999999999799
# sent|orthographic representations --> prob = 0.00020065241321240405, entropy = 4.665206077661126, freq = 0.0002006524132124, marginal prob = 0.9999999999999799
# finder|orthographic representations --> prob = 2.653940012567096e-06, entropy = 4.656904898435276, freq = 2.643076615418973e-06, marginal prob = 0.9959066907704462
# his|orthographic representations --> prob = 0.0044835435779882905, entropy = 4.665206077661126, freq = 0.0044835435779882, marginal prob = 0.9999999999999799
# home|orthographic representations --> prob = 0.000893941096105018, entropy = 4.665206077661126, freq = 0.000893941096105, marginal prob = 0.9999999999999799
# also|orthographic representations --> prob = 0.0021449051067536427, entropy = 4.665206077661126, freq = 0.0021449051067536, marginal prob = 0.9999999999999799
# included|orthographic representations --> prob = 0.00014806764285330297, entropy = 4.665206077661126, freq = 0.0001480676428533, marginal prob = 0.9999999999999799
# two|orthographic representations --> prob = 0.0017436280280975157, entropy = 4.66508858238042, freq = 0.0017436002803287, marginal prob = 0.9999840861878976
# stamps|orthographic representations --> prob = 1.1250373237359519e-05, entropy = 4.665206077661126, freq = 1.1250373237359294e-05, marginal prob = 0.9999999999999799
# were|orthographic representations --> prob = 0.0030305433443809605, entropy = 4.665206077661126, freq = 0.0030305433443809, marginal prob = 0.9999999999999799
# so|orthographic representations --> prob = 0.004580410260228692, entropy = 4.665206077661126, freq = 0.0045804102602286, marginal prob = 0.9999999999999799
# would|orthographic representations --> prob = 0.0025738861281043514, entropy = 4.665206077661126, freq = 0.0025738861281043, marginal prob = 0.9999999999999799
# not|orthographic representations --> prob = 0.006780667756834136, entropy = 4.665206077661126, freq = 0.006780667756834, marginal prob = 0.9999999999999799
# incur|orthographic representations --> prob = 2.7676194925853675e-06, entropy = 4.665206077661126, freq = 2.767619492585312e-06, marginal prob = 0.9999999999999799
# cost|orthographic representations --> prob = 0.00024078289585490484, entropy = 4.665206077661126, freq = 0.0002407828958549, marginal prob = 0.9999999999999799
# did|orthographic representations --> prob = 0.0012620344886189255, entropy = 4.665206077661126, freq = 0.0012620344886189, marginal prob = 0.9999999999999799
# think|orthographic representations --> prob = 0.0016610119434443144, entropy = 4.663840424808964, freq = 0.0016605716955511, marginal prob = 0.9997349520002238
# take|orthographic representations --> prob = 0.0011513297089154233, entropy = 4.665206077661126, freq = 0.0011513297089154, marginal prob = 0.9999999999999799
# She|orthographic representations --> prob = 0.0025186930206647622, entropy = 4.664826402164039, freq = 0.0025185337382526, marginal prob = 0.9999367598945742
# moved|orthographic representations --> prob = 0.00014114859412180285, entropy = 4.665206077661126, freq = 0.0001411485941218, marginal prob = 0.9999999999999799
# arrival|orthographic representations --> prob = 3.8054768023048816e-05, entropy = 4.665206077661126, freq = 3.805476802304805e-05, marginal prob = 0.9999999999999799
# known|orthographic representations --> prob = 0.0003390333878417068, entropy = 4.665206077661126, freq = 0.0003390333878417, marginal prob = 0.9999999999999799
# because|orthographic representations --> prob = 0.0014806764285331298, entropy = 4.665206077661126, freq = 0.0014806764285331, marginal prob = 0.9999999999999799
# age|orthographic representations --> prob = 0.0002892162369751058, entropy = 4.665206077661126, freq = 0.0002892162369751, marginal prob = 0.9999999999999799
# I|orthographic representations --> prob = 0.017020859879399945, entropy = 4.665206077661126, freq = 0.0170208598793996, marginal prob = 0.9999999999999799
# little|orthographic representations --> prob = 0.0007780218067323771, entropy = 4.663391668155077, freq = 0.0007777010774164, marginal prob = 0.9995877630765593
# but|orthographic representations --> prob = 0.005914793519687692, entropy = 4.6619565645716134, freq = 0.0059088676166696, marginal prob = 0.998998121743664
# writer|orthographic representations --> prob = 6.781207331129948e-05, entropy = 4.6647466380444484, freq = 6.780667756834015e-05, marginal prob = 0.9999204309395681
# open|orthographic representations --> prob = 0.00041791054338030843, entropy = 4.665206077661126, freq = 0.0004179105433803, marginal prob = 0.9999999999999799
# minded|orthographic representations --> prob = 1.9536372999234402e-05, entropy = 4.6614035736403725, freq = 1.951171742272645e-05, marginal prob = 0.998737965511361
# believed|orthographic representations --> prob = 7.777010774164882e-05, entropy = 4.665206077661126, freq = 7.777010774164726e-05, marginal prob = 0.9999999999999799
# freedom|orthographic representations --> prob = 0.00010018782563150202, entropy = 4.665206077661126, freq = 0.0001001878256315, marginal prob = 0.9999999999999799
# everyone|orthographic representations --> prob = 0.0004082238751563082, entropy = 4.665206077661126, freq = 0.0004082238751563, marginal prob = 0.9999999999999799
# should|orthographic representations --> prob = 0.0013519821221279272, entropy = 4.665206077661126, freq = 0.0013519821221279, marginal prob = 0.9999999999999799
# respect|orthographic representations --> prob = 0.00014806764285330297, entropy = 4.665206077661126, freq = 0.0001480676428533, marginal prob = 0.9999999999999799
# each|orthographic representations --> prob = 0.0006780667756834136, entropy = 4.665206077661126, freq = 0.0006780667756834, marginal prob = 0.9999999999999799
# other|orthographic representations --> prob = 0.0020065241321243405, entropy = 4.665206077661126, freq = 0.0020065241321243, marginal prob = 0.9999999999999799
# lot|orthographic representations --> prob = 0.0005632105667411113, entropy = 4.665206077661126, freq = 0.0005632105667411, marginal prob = 0.9999999999999799
# young|orthographic representations --> prob = 0.000372255330416016, entropy = 4.665013830246003, freq = 0.0003722448217527, marginal prob = 0.9999717702811556
# later|orthographic representations --> prob = 0.00042759721160440863, entropy = 4.665206077661126, freq = 0.0004275972116044, marginal prob = 0.9999999999999799
# traveled|orthographic representations --> prob = 1.5913812082365863e-05, entropy = 4.665206077661126, freq = 1.5913812082365544e-05, marginal prob = 0.9999999999999799
# wife|orthographic representations --> prob = 0.0002352476568697047, entropy = 4.665206077661126, freq = 0.0002352476568697, marginal prob = 0.9999999999999799
# daughters|orthographic representations --> prob = 2.643076615419026e-05, entropy = 4.665206077661126, freq = 2.643076615418973e-05, marginal prob = 0.9999999999999799
# wonderful|orthographic representations --> prob = 9.7973730037522e-05, entropy = 4.665206077661126, freq = 9.797373003752004e-05, marginal prob = 0.9999999999999799
# could|orthographic representations --> prob = 0.0015919341446667286, entropy = 4.663712069330654, freq = 0.0015913812082365, marginal prob = 0.9996526637536604
# see|orthographic representations --> prob = 0.0017436002803287351, entropy = 4.665206077661126, freq = 0.0017436002803287, marginal prob = 0.9999999999999799
# where|orthographic representations --> prob = 0.0013838097462926277, entropy = 4.665206077661126, freq = 0.0013838097462926, marginal prob = 0.9999999999999799
# roots|orthographic representations --> prob = 3.0305433443809777e-05, entropy = 4.665206077661126, freq = 3.0305433443809167e-05, marginal prob = 0.9999999999999799
# came|orthographic representations --> prob = 0.00043728387982840876, entropy = 4.665206077661126, freq = 0.0004372838798284, marginal prob = 0.9999999999999799
# Like|orthographic representations --> prob = 0.0035563910479721717, entropy = 4.665206077661126, freq = 0.0035563910479721, marginal prob = 0.9999999999999799
# liked|orthographic representations --> prob = 7.979531413377989e-05, entropy = 4.658632381227552, freq = 7.956906041182773e-05, marginal prob = 0.9971645738298262
# culture|orthographic representations --> prob = 0.00014806764285330297, entropy = 4.665206077661126, freq = 0.0001480676428533, marginal prob = 0.9999999999999799
# traveling|orthographic representations --> prob = 2.5738861281043928e-05, entropy = 4.665206077661126, freq = 2.573886128104341e-05, marginal prob = 0.9999999999999799
# around|orthographic representations --> prob = 0.0008150639405663163, entropy = 4.665206077661126, freq = 0.0008150639405663, marginal prob = 0.9999999999999799
# herself|orthographic representations --> prob = 8.344372770144884e-05, entropy = 4.665206077661126, freq = 8.344372770144716e-05, marginal prob = 0.9999999999999799
# too|orthographic representations --> prob = 0.0012329744839467247, entropy = 4.665206077661126, freq = 0.0012329744839467, marginal prob = 0.9999999999999799
# What|orthographic representations --> prob = 0.003321143391102367, entropy = 4.665206077661126, freq = 0.0033211433911023, marginal prob = 0.9999999999999799
# taught|orthographic representations --> prob = 6.695960709147204e-05, entropy = 4.642766080173318, freq = 6.628448684741822e-05, marginal prob = 0.9899174999170537
# mother|orthographic representations --> prob = 0.00024078289585490484, entropy = 4.665206077661126, freq = 0.0002407828958549, marginal prob = 0.9999999999999799
# sons|orthographic representations --> prob = 4.3728387982848816e-05, entropy = 4.665206077661126, freq = 4.3728387982847935e-05, marginal prob = 0.9999999999999799
# Despite|orthographic representations --> prob = 0.0001383809746292028, entropy = 4.665206077661126, freq = 0.0001383809746292, marginal prob = 0.9999999999999799
# joy|orthographic representations --> prob = 4.9125245993390284e-05, entropy = 4.665206077661126, freq = 4.9125245993389295e-05, marginal prob = 0.9999999999999799
# receiving|orthographic representations --> prob = 5.3830199130785406e-05, entropy = 4.665206077661126, freq = 5.383019913078432e-05, marginal prob = 0.9999999999999799
# hoped|orthographic representations --> prob = 2.643076615419026e-05, entropy = 4.665206077661126, freq = 2.643076615418973e-05, marginal prob = 0.9999999999999799
# others|orthographic representations --> prob = 0.00036430695449123676, entropy = 4.6619565645716134, freq = 0.0003639419632749, marginal prob = 0.998998121743664
# repeat|orthographic representations --> prob = 4.275972116044393e-05, entropy = 4.665206077661126, freq = 4.275972116044307e-05, marginal prob = 0.9999999999999799
# what|orthographic representations --> prob = 0.003321143391102367, entropy = 4.665206077661126, freq = 0.0033211433911023, marginal prob = 0.9999999999999799
# done|orthographic representations --> prob = 0.0005258477035912105, entropy = 4.665206077661126, freq = 0.0005258477035912, marginal prob = 0.9999999999999799
# throw|orthographic representations --> prob = 9.354553884938544e-05, entropy = 4.665206077661126, freq = 9.354553884938356e-05, marginal prob = 0.9999999999999799
# bottles|orthographic representations --> prob = 2.146399121389537e-05, entropy = 4.662273342990351, freq = 2.144905106753617e-05, marginal prob = 0.9993039436975948
# messages|orthographic representations --> prob = 4.801819819635613e-05, entropy = 4.665206077661126, freq = 4.801819819635517e-05, marginal prob = 0.9999999999999799
# Today|orthographic representations --> prob = 0.0004912748263701843, entropy = 4.664886304222409, freq = 0.0004912524599338, marginal prob = 0.9999544726593269
# full|orthographic representations --> prob = 0.0004803528142083415, entropy = 4.6636847490591204, freq = 0.0004801819819635, marginal prob = 0.9996443608951827
# many|orthographic representations --> prob = 0.0011250373237359226, entropy = 4.665206077661126, freq = 0.0011250373237359, marginal prob = 0.9999999999999799
# rubbish|orthographic representations --> prob = 1.0254030220028791e-05, entropy = 4.665206077661126, freq = 1.0254030220028584e-05, marginal prob = 0.9999999999999799
# more|orthographic representations --> prob = 0.003168924319010164, entropy = 4.665206077661126, freq = 0.0031689243190101, marginal prob = 0.9999999999999799
# shouldn|orthographic representations --> prob = 2.961352857066343e-07, entropy = 4.665206077661126, freq = 2.961352857066284e-07, marginal prob = 0.9999999999999799
# t|orthographic representations --> prob = 0.0003722448217527075, entropy = 4.665206077661126, freq = 0.0003722448217527, marginal prob = 0.9999999999999799
# thrown|orthographic representations --> prob = 3.473362463194637e-05, entropy = 4.665206077661126, freq = 3.473362463194567e-05, marginal prob = 0.9999999999999799
# there|orthographic representations --> prob = 0.0028229718824370567, entropy = 4.665206077661126, freq = 0.002822971882437, marginal prob = 0.9999999999999799
# will|orthographic representations --> prob = 0.003907983010093187, entropy = 4.66077546298572, freq = 0.0039023434845452, marginal prob = 0.9985569216822535
# display|orthographic representations --> prob = 5.910503419117134e-05, entropy = 4.663952827156913, freq = 5.908867616669641e-05, marginal prob = 0.9997232380507214
# until|orthographic representations --> prob = 0.0005633282771543149, entropy = 4.664201194069197, freq = 0.0005632105667411, marginal prob = 0.9997910447282897
# beginning|orthographic representations --> prob = 0.0001383809746292028, entropy = 4.665206077661126, freq = 0.0001383809746292, marginal prob = 0.9999999999999799
# May|orthographic representations --> prob = 0.0013215383077094264, entropy = 4.665206077661126, freq = 0.0013215383077094, marginal prob = 0.9999999999999799
# experts|orthographic representations --> prob = 4.5804102602287835e-05, entropy = 4.665206077661126, freq = 4.5804102602286914e-05, marginal prob = 0.9999999999999799
# attempt|orthographic representations --> prob = 9.7973730037522e-05, entropy = 4.665206077661126, freq = 9.797373003752004e-05, marginal prob = 0.9999999999999799
# decipher|orthographic representations --> prob = 1.9096574498839037e-06, entropy = 4.665206077661126, freq = 1.909657449883865e-06, marginal prob = 0.9999999999999799
# rest|orthographic representations --> prob = 0.0002352476568697047, entropy = 4.665206077661126, freq = 0.0002352476568697, marginal prob = 0.9999999999999799
# text|orthographic representations --> prob = 0.00014114859412180285, entropy = 4.665206077661126, freq = 0.0001411485941218, marginal prob = 0.9999999999999799
# clear|orthographic representations --> prob = 0.00024631863931004293, entropy = 4.665186757612892, freq = 0.00024631813484, marginal prob = 0.9999979519615554
# happen|orthographic representations --> prob = 0.0002144905106753043, entropy = 4.665206077661126, freq = 0.0002144905106753, marginal prob = 0.9999999999999799
# hopes|orthographic representations --> prob = 3.473362463194637e-05, entropy = 4.665206077661126, freq = 3.473362463194567e-05, marginal prob = 0.9999999999999799
# stay|orthographic representations --> prob = 0.00029613528570660594, entropy = 4.665206077661126, freq = 0.0002961352857066, marginal prob = 0.9999999999999799
# We|orthographic representations --> prob = 0.0048023396126145364, entropy = 4.66456435113816, freq = 0.0048018198196355, marginal prob = 0.9998917625530541
# want|orthographic representations --> prob = 0.0015221907209219305, entropy = 4.665206077661126, freq = 0.0015221907209219, marginal prob = 0.9999999999999799
# make|orthographic representations --> prob = 0.0016605716955511334, entropy = 4.665206077661126, freq = 0.0016605716955511, marginal prob = 0.9999999999999799
# few|orthographic representations --> prob = 0.000550756279024411, entropy = 4.665206077661126, freq = 0.0005507562790244, marginal prob = 0.9999999999999799
# photos|orthographic representations --> prob = 9.35587445346443e-05, entropy = 4.664471941967091, freq = 9.354553884938356e-05, marginal prob = 0.9998588514058581
# available|orthographic representations --> prob = 0.0002643076615418053, entropy = 4.665206077661126, freq = 0.0002643076615418, marginal prob = 0.9999999999999799
# put|orthographic representations --> prob = 0.0006324010540557127, entropy = 4.665206077661126, freq = 0.0006324010540557, marginal prob = 0.9999999999999799
# give|orthographic representations --> prob = 0.0007098943998481143, entropy = 4.665206077661126, freq = 0.0007098943998481, marginal prob = 0.9999999999999799
# face|orthographic representations --> prob = 0.00039023434845450786, entropy = 4.665206077661126, freq = 0.0003902343484545, marginal prob = 0.9999999999999799
# visitors|orthographic representations --> prob = 4.2769143310134555e-05, entropy = 4.663974641583713, freq = 4.275972116044307e-05, marginal prob = 0.99977969748837
# can|orthographic representations --> prob = 0.00398537206932288, entropy = 4.665206077661126, freq = 0.0039853720693228, marginal prob = 0.9999999999999799
# Inky|orthographic representations --> prob = 5.509659478378238e-07, entropy = 4.663603932027263, freq = 5.507562790244771e-07, marginal prob = 0.9996194523197495
# Octopus|orthographic representations --> prob = 3.98537206932293e-06, entropy = 4.665206077661126, freq = 3.985372069322849e-06, marginal prob = 0.9999999999999799
# Escapes|orthographic representations --> prob = 5.023229379042443e-06, entropy = 4.665206077661126, freq = 5.023229379042342e-06, marginal prob = 0.9999999999999799
# Aquarium|orthographic representations --> prob = 5.023229379042443e-06, entropy = 4.665206077661126, freq = 5.023229379042342e-06, marginal prob = 0.9999999999999799
# An|orthographic representations --> prob = 0.004691115039932195, entropy = 4.665206077661126, freq = 0.0046911150399321, marginal prob = 0.9999999999999799
# octopus|orthographic representations --> prob = 3.98537206932293e-06, entropy = 4.665206077661126, freq = 3.985372069322849e-06, marginal prob = 0.9999999999999799
# has|orthographic representations --> prob = 0.0032381148063248652, entropy = 4.665206077661126, freq = 0.0032381148063248, marginal prob = 0.9999999999999799
# made|orthographic representations --> prob = 0.0011513297089154233, entropy = 4.665206077661126, freq = 0.0011513297089154, marginal prob = 0.9999999999999799
# brazen|orthographic representations --> prob = 1.7436002803287816e-06, entropy = 4.665206077661126, freq = 1.7436002803287467e-06, marginal prob = 0.9999999999999799
# escape|orthographic representations --> prob = 6.0472485912990285e-05, entropy = 4.665206077661126, freq = 6.047248591298907e-05, marginal prob = 0.9999999999999799
# National|orthographic representations --> prob = 0.0004483547406088451, entropy = 4.665197276275015, freq = 0.0004483543577988, marginal prob = 0.9999991461893665
# New|orthographic representations --> prob = 0.00246411906319426, entropy = 4.663603932027263, freq = 0.0024631813484009, marginal prob = 0.9996194523197495
# Zealand|orthographic representations --> prob = 4.3728387982848816e-05, entropy = 4.665206077661126, freq = 4.3728387982847935e-05, marginal prob = 0.9999999999999799
# breaking|orthographic representations --> prob = 7.618586500768744e-05, entropy = 4.6619565645716134, freq = 7.610953604609609e-05, marginal prob = 0.998998121743664
# its|orthographic representations --> prob = 0.0019096574498838385, entropy = 4.665206077661126, freq = 0.0019096574498838, marginal prob = 0.9999999999999799
# tank|orthographic representations --> prob = 5.1478541781928034e-05, entropy = 4.66508858238042, freq = 5.147772256208681e-05, marginal prob = 0.9999840861878976
# slithering|orthographic representations --> prob = 3.3903338784170754e-07, entropy = 4.665206077661126, freq = 3.390333878417007e-07, marginal prob = 0.9999999999999799
# meter|orthographic representations --> prob = 1.7020859879400014e-05, entropy = 4.665206077661126, freq = 1.702085987939967e-05, marginal prob = 0.9999999999999799
# drainpipe|orthographic representations --> prob = 1.5221907209219524e-07, entropy = 4.665206077661126, freq = 1.5221907209219217e-07, marginal prob = 0.9999999999999799
# disappearing|orthographic representations --> prob = 5.507562790244882e-06, entropy = 4.665206077661126, freq = 5.507562790244771e-06, marginal prob = 0.9999999999999799
# In|orthographic representations --> prob = 0.025738861281043916, entropy = 4.665206077661126, freq = 0.0257388612810434, marginal prob = 0.9999999999999799
# scenes|orthographic representations --> prob = 5.258477035912199e-05, entropy = 4.665206077661126, freq = 5.258477035912093e-05, marginal prob = 0.9999999999999799
# reminiscent|orthographic representations --> prob = 5.632105667411224e-06, entropy = 4.665206077661126, freq = 5.63210566741111e-06, marginal prob = 0.9999999999999799
# Finding|orthographic representations --> prob = 9.810258898610375e-05, entropy = 4.66108339049019, freq = 9.797373003752004e-05, marginal prob = 0.9986864877887988
# Nemo|orthographic representations --> prob = 2.048038424513172e-06, entropy = 4.665206077661126, freq = 2.048038424513131e-06, marginal prob = 0.9999999999999799
# common|orthographic representations --> prob = 0.00021864193991420438, entropy = 4.665206077661126, freq = 0.0002186419399142, marginal prob = 0.9999999999999799
# dash|orthographic representations --> prob = 1.3838097462926842e-05, entropy = 4.665206077661126, freq = 1.3838097462926564e-05, marginal prob = 0.9999999999999799
# lid|orthographic representations --> prob = 8.939410961050738e-06, entropy = 4.665206077661126, freq = 8.939410961050558e-06, marginal prob = 0.9999999999999799
# accidentally|orthographic representations --> prob = 2.2971241788458552e-05, entropy = 4.665206077661126, freq = 2.297124178845809e-05, marginal prob = 0.9999999999999799
# left|orthographic representations --> prob = 0.0005770486642040116, entropy = 4.665206077661126, freq = 0.000577048664204, marginal prob = 0.9999999999999799
# slightly|orthographic representations --> prob = 7.777010774164882e-05, entropy = 4.665206077661126, freq = 7.777010774164726e-05, marginal prob = 0.9999999999999799
# ajar|orthographic representations --> prob = 5.147772256208784e-07, entropy = 4.665206077661126, freq = 5.147772256208681e-07, marginal prob = 0.9999999999999799
# Staff|orthographic representations --> prob = 0.00016605716955510333, entropy = 4.665206077661126, freq = 0.0001660571695551, marginal prob = 0.9999999999999799
# middle|orthographic representations --> prob = 0.00020899862491878947, entropy = 4.66407700942693, freq = 0.0002089552716901, marginal prob = 0.9997925669190105
# night|orthographic representations --> prob = 0.0005632105667411113, entropy = 4.665206077661126, freq = 0.0005632105667411, marginal prob = 0.9999999999999799
# aquarium|orthographic representations --> prob = 5.023229379042443e-06, entropy = 4.665206077661126, freq = 5.023229379042342e-06, marginal prob = 0.9999999999999799
# deserted|orthographic representations --> prob = 6.047248591299028e-06, entropy = 4.665206077661126, freq = 6.047248591298907e-06, marginal prob = 0.9999999999999799
# ...
# France|orthographic representations --> prob = 0.00012052982890200243, entropy = 4.665206077661126, freq = 0.000120529828902, marginal prob = 0.9999999999999799
# unforgiving|orthographic representations --> prob = 1.2329744839467814e-06, entropy = 4.665206077661126, freq = 1.2329744839467566e-06, marginal prob = 0.9999999999999799
# may|orthographic representations --> prob = 0.0013215383077094264, entropy = 4.665206077661126, freq = 0.0013215383077094, marginal prob = 0.9999999999999799
# helped|orthographic representations --> prob = 0.0001052916632633702, entropy = 4.659107555687351, freq = 0.0001050311597436, marginal prob = 0.9975258865545832
# turn|orthographic representations --> prob = 0.00028950628702914706, entropy = 4.6619565645716134, freq = 0.0002892162369751, marginal prob = 0.998998121743664
# economic|orthographic representations --> prob = 0.00017436002803280349, entropy = 4.665206077661126, freq = 0.0001743600280328, marginal prob = 0.9999999999999799
# superpower|orthographic representations --> prob = 2.297124178845855e-06, entropy = 4.665206077661126, freq = 2.297124178845809e-06, marginal prob = 0.9999999999999799
# corporate|orthographic representations --> prob = 6.0472485912990285e-05, entropy = 4.665206077661126, freq = 6.047248591298907e-05, marginal prob = 0.9999999999999799
# foot|orthographic representations --> prob = 0.00010254030220020205, entropy = 4.665206077661126, freq = 0.0001025403022002, marginal prob = 0.9999999999999799
# soldiers|orthographic representations --> prob = 6.932886828926346e-05, entropy = 4.665206077661126, freq = 6.932886828926206e-05, marginal prob = 0.9999999999999799
# revered|orthographic representations --> prob = 3.0305433443809778e-06, entropy = 4.665206077661126, freq = 3.030543344380917e-06, marginal prob = 0.9999999999999799
# commitment|orthographic representations --> prob = 3.7224482175273194e-05, entropy = 4.665206077661126, freq = 3.722448217527245e-05, marginal prob = 0.9999999999999799
# often|orthographic representations --> prob = 0.00035563910479720714, entropy = 4.665206077661126, freq = 0.0003556391047972, marginal prob = 0.9999999999999799
# exclusion|orthographic representations --> prob = 6.628448684741955e-06, entropy = 4.665206077661126, freq = 6.628448684741822e-06, marginal prob = 0.9999999999999799
# everything|orthographic representations --> prob = 0.0004801819819635096, entropy = 4.665206077661126, freq = 0.0004801819819635, marginal prob = 0.9999999999999799
# else|orthographic representations --> prob = 0.00033211433911020666, entropy = 4.665206077661126, freq = 0.0003321143391102, marginal prob = 0.9999999999999799
# low|orthographic representations --> prob = 0.00029613528570660594, entropy = 4.665206077661126, freq = 0.0002961352857066, marginal prob = 0.9999999999999799
# birth|orthographic representations --> prob = 8.15157228028539e-05, entropy = 4.664511738593282, freq = 8.150639405663745e-05, marginal prob = 0.9998855589339616
# rate|orthographic representations --> prob = 0.00019096574498830385, entropy = 4.665206077661126, freq = 0.0001909657449883, marginal prob = 0.9999999999999799
# predictions|orthographic representations --> prob = 1.2052982890209276e-05, entropy = 4.665206077661126, freq = 1.2052982890209034e-05, marginal prob = 0.9999999999999799
# rapid|orthographic representations --> prob = 3.321144071285509e-05, entropy = 4.665203674081294, freq = 3.321143391102375e-05, marginal prob = 0.9999997951961374
# population|orthographic representations --> prob = 0.00014114859412180285, entropy = 4.665206077661126, freq = 0.0001411485941218, marginal prob = 0.9999999999999799
# decline|orthographic representations --> prob = 3.473362463194637e-05, entropy = 4.665206077661126, freq = 3.473362463194567e-05, marginal prob = 0.9999999999999799
# partly|orthographic representations --> prob = 2.767619492585368e-05, entropy = 4.665206077661126, freq = 2.7676194925853125e-05, marginal prob = 0.9999999999999799
# blamed|orthographic representations --> prob = 1.098744938556391e-05, entropy = 4.665206077661126, freq = 1.098744938556369e-05, marginal prob = 0.9999999999999799
# lack|orthographic representations --> prob = 0.00011513297089150232, entropy = 4.665206077661126, freq = 0.0001151329708915, marginal prob = 0.9999999999999799
# couples|orthographic representations --> prob = 3.0335826248515543e-05, entropy = 4.6619565645716134, freq = 3.0305433443809167e-05, marginal prob = 0.998998121743664
# start|orthographic representations --> prob = 0.0005023229379042101, entropy = 4.665206077661126, freq = 0.0005023229379042, marginal prob = 0.9999999999999799
# families|orthographic representations --> prob = 0.00012052982890200243, entropy = 4.665206077661126, freq = 0.000120529828902, marginal prob = 0.9999999999999799
# More|orthographic representations --> prob = 0.003168924319010164, entropy = 4.665206077661126, freq = 0.0031689243190101, marginal prob = 0.9999999999999799
# falling|orthographic representations --> prob = 6.885339403249423e-05, entropy = 4.736102872675577, freq = 6.324010540557438e-05, marginal prob = 0.9184747722926956
# ill|orthographic representations --> prob = 7.265001168036591e-05, entropy = 4.665206077661126, freq = 7.265001168036444e-05, marginal prob = 0.9999999999999799
# stress|orthographic representations --> prob = 7.431058337591712e-05, entropy = 4.665206077661126, freq = 7.431058337591563e-05, marginal prob = 0.9999999999999799
# worse|orthographic representations --> prob = 0.00010738363631230215, entropy = 4.665206077661126, freq = 0.0001073836363123, marginal prob = 0.9999999999999799
# succumbing|orthographic representations --> prob = 7.777010774164884e-07, entropy = 4.665206077661126, freq = 7.777010774164727e-07, marginal prob = 0.9999999999999799
# karoshi|orthographic representations --> prob = 2.6430766154190266e-08, entropy = 4.665206077661126, freq = 2.6430766154189734e-08, marginal prob = 0.9999999999999799
# death|orthographic representations --> prob = 0.000347336246319407, entropy = 4.665206077661126, freq = 0.0003473362463194, marginal prob = 0.9999999999999799
# studies|orthographic representations --> prob = 0.00013217907244594416, entropy = 4.664270526837262, freq = 0.0001321538307709, marginal prob = 0.9998090342549916
# suggesting|orthographic representations --> prob = 2.463181348400977e-05, entropy = 4.665206077661126, freq = 2.4631813484009275e-05, marginal prob = 0.9999999999999799
# longer|orthographic representations --> prob = 0.00020065241321240405, entropy = 4.665206077661126, freq = 0.0002006524132124, marginal prob = 0.9999999999999799
# workshop|orthographic representations --> prob = 1.9511717422726844e-05, entropy = 4.665206077661126, freq = 1.951171742272645e-05, marginal prob = 0.9999999999999799
# factory|orthographic representations --> prob = 4.9125245993390284e-05, entropy = 4.665206077661126, freq = 4.9125245993389295e-05, marginal prob = 0.9999999999999799
# necessarily|orthographic representations --> prob = 4.179105433803905e-05, entropy = 4.665206077661126, freq = 4.179105433803821e-05, marginal prob = 0.9999999999999799
# people|orthographic representations --> prob = 0.00246352907206605, entropy = 4.664471941967091, freq = 0.0024631813484009, marginal prob = 0.9998588514058581
# productive|orthographic representations --> prob = 2.2971241788458552e-05, entropy = 4.665206077661126, freq = 2.297124178845809e-05, marginal prob = 0.9999999999999799
# today|orthographic representations --> prob = 0.0004912524599338099, entropy = 4.665206077661126, freq = 0.0004912524599338, marginal prob = 0.9999999999999799
# still|orthographic representations --> prob = 0.0011519100932044985, entropy = 4.6629455785295475, freq = 0.0011513297089154, marginal prob = 0.9994961548713548
# nursing|orthographic representations --> prob = 2.8921623697517094e-05, entropy = 4.665206077661126, freq = 2.892162369751651e-05, marginal prob = 0.9999999999999799
# collective|orthographic representations --> prob = 2.767619492585368e-05, entropy = 4.665206077661126, freq = 2.7676194925853125e-05, marginal prob = 0.9999999999999799
# hangover|orthographic representations --> prob = 4.372838798284881e-06, entropy = 4.665206077661126, freq = 4.372838798284793e-06, marginal prob = 0.9999999999999799
# bubble|orthographic representations --> prob = 2.0069404379627603e-05, entropy = 4.66407700942693, freq = 2.0065241321243514e-05, marginal prob = 0.9997925669190105
# About|orthographic representations --> prob = 0.003473801830382393, entropy = 4.6644466826395155, freq = 0.0034733624631945, marginal prob = 0.9998735197891687
# compared|orthographic representations --> prob = 0.00011513297089150232, entropy = 4.665206077661126, freq = 0.0001151329708915, marginal prob = 0.9999999999999799
# US|orthographic representations --> prob = 0.0015221907209219305, entropy = 4.665206077661126, freq = 0.0015221907209219, marginal prob = 0.9999999999999799
# according|orthographic representations --> prob = 0.0002643076615418053, entropy = 4.665206077661126, freq = 0.0002643076615418, marginal prob = 0.9999999999999799
# data|orthographic representations --> prob = 0.00030305433443800607, entropy = 4.665206077661126, freq = 0.000303054334438, marginal prob = 0.9999999999999799
# spending|orthographic representations --> prob = 7.098943998481468e-05, entropy = 4.665206077661126, freq = 7.098943998481325e-05, marginal prob = 0.9999999999999799
# Erika|orthographic representations --> prob = 2.0493383133979157e-06, entropy = 4.662398543703168, freq = 2.048038424513131e-06, marginal prob = 0.9993657031265719
# Sekiguchi|orthographic representations --> prob = 6.047248591299029e-08, entropy = 4.665206077661126, freq = 6.047248591298907e-08, marginal prob = 0.9999999999999799
# extreme|orthographic representations --> prob = 5.5075627902448816e-05, entropy = 4.665206077661126, freq = 5.507562790244771e-05, marginal prob = 0.9999999999999799
# trading|orthographic representations --> prob = 5.90886761666976e-05, entropy = 4.665206077661126, freq = 5.908867616669641e-05, marginal prob = 0.9999999999999799
# employee|orthographic representations --> prob = 4.3728387982848816e-05, entropy = 4.665206077661126, freq = 4.3728387982847935e-05, marginal prob = 0.9999999999999799
# used|orthographic representations --> prob = 0.0008731839499106175, entropy = 4.665206077661126, freq = 0.0008731839499106, marginal prob = 0.9999999999999799
# counted|orthographic representations --> prob = 1.5221907209219523e-05, entropy = 4.665206077661126, freq = 1.5221907209219216e-05, marginal prob = 0.9999999999999799
# sick|orthographic representations --> prob = 0.00010503115974360211, entropy = 4.665206077661126, freq = 0.0001050311597436, marginal prob = 0.9999999999999799
# Nobody|orthographic representations --> prob = 0.0001235431181603261, entropy = 4.659554601202021, freq = 0.0001232974483946, marginal prob = 0.9980114653945574
# uses|orthographic representations --> prob = 0.00010503115974360211, entropy = 4.665206077661126, freq = 0.0001050311597436, marginal prob = 0.9999999999999799
# faces|orthographic representations --> prob = 5.3830199130785406e-05, entropy = 4.665206077661126, freq = 5.383019913078432e-05, marginal prob = 0.9999999999999799
# dilemma|orthographic representations --> prob = 7.4310583375917125e-06, entropy = 4.665206077661126, freq = 7.431058337591563e-06, marginal prob = 0.9999999999999799
# criticism|orthographic representations --> prob = 4.275972116044393e-05, entropy = 4.665206077661126, freq = 4.275972116044307e-05, marginal prob = 0.9999999999999799
# leaving|orthographic representations --> prob = 0.00013215383077090265, entropy = 4.665206077661126, freq = 0.0001321538307709, marginal prob = 0.9999999999999799
# colleagues|orthographic representations --> prob = 2.6984290052707334e-05, entropy = 4.665206077661126, freq = 2.6984290052706792e-05, marginal prob = 0.9999999999999799
# lurch|orthographic representations --> prob = 8.583796172527418e-07, entropy = 4.654889716001712, freq = 8.538106134625688e-07, marginal prob = 0.9946771758108653
# Yuu|orthographic representations --> prob = 3.3903338784170754e-07, entropy = 4.665206077661126, freq = 3.390333878417007e-07, marginal prob = 0.9999999999999799
# Wakebe|orthographic representations --> prob = 0.0, entropy = 4.665206077661126, freq = 0.0, marginal prob = 0.9999999999999799
# health|orthographic representations --> prob = 0.000415399946824015, entropy = 4.723983159781957, freq = 0.0003805476802304, marginal prob = 0.9160994919231893
# ministry|orthographic representations --> prob = 5.90886761666976e-05, entropy = 4.665206077661126, freq = 5.908867616669641e-05, marginal prob = 0.9999999999999799
# official|orthographic representations --> prob = 0.0001912621780276456, entropy = 4.6590711232959565, freq = 0.0001909657449883, marginal prob = 0.9984501220136542
# overseeing|orthographic representations --> prob = 3.3211433911024412e-06, entropy = 4.665206077661126, freq = 3.3211433911023743e-06, marginal prob = 0.9999999999999799
# policy|orthographic representations --> prob = 0.0002050136385059733, entropy = 4.661804402427753, freq = 0.0002048038424513, marginal prob = 0.9989766726925965
# working|orthographic representations --> prob = 0.00039023434845450786, entropy = 4.665206077661126, freq = 0.0003902343484545, marginal prob = 0.9999999999999799
# admits|orthographic representations --> prob = 1.2057733283044682e-05, entropy = 4.662991473291813, freq = 1.2052982890209034e-05, marginal prob = 0.9996060293652101
# putting|orthographic representations --> prob = 0.00010020879945589642, entropy = 4.664059209246171, freq = 0.0001001878256315, marginal prob = 0.999790698775853
# overtime|orthographic representations --> prob = 1.2052982890209276e-05, entropy = 4.665206077661126, freq = 1.2052982890209034e-05, marginal prob = 0.9999999999999799
# month|orthographic representations --> prob = 0.0002463181348400049, entropy = 4.665206077661126, freq = 0.00024631813484, marginal prob = 0.9999999999999799
# blames|orthographic representations --> prob = 4.912524599339028e-06, entropy = 4.665206077661126, freq = 4.912524599338929e-06, marginal prob = 0.9999999999999799
# irresistible|orthographic representations --> prob = 4.0822387515634185e-06, entropy = 4.665206077661126, freq = 4.082238751563336e-06, marginal prob = 0.9999999999999799
# pressure|orthographic representations --> prob = 0.00014114859412180285, entropy = 4.665206077661126, freq = 0.0001411485941218, marginal prob = 0.9999999999999799
# match|orthographic representations --> prob = 0.00018681695264452614, entropy = 4.665100171397629, freq = 0.0001868143157495, marginal prob = 0.9999858851405677
# hour|orthographic representations --> prob = 0.0002089552716901042, entropy = 4.665206077661126, freq = 0.0002089552716901, marginal prob = 0.9999999999999799
# worker|orthographic representations --> prob = 3.7224482175273194e-05, entropy = 4.665206077661126, freq = 3.722448217527245e-05, marginal prob = 0.9999999999999799
# vacations|orthographic representations --> prob = 4.4835435779882955e-06, entropy = 4.665206077661126, freq = 4.483543577988206e-06, marginal prob = 0.9999999999999799
# unfortunately|orthographic representations --> prob = 5.770486642040492e-05, entropy = 4.665206077661126, freq = 5.770486642040376e-05, marginal prob = 0.9999999999999799
# involves|orthographic representations --> prob = 3.0305433443809777e-05, entropy = 4.665206077661126, freq = 3.0305433443809167e-05, marginal prob = 0.9999999999999799
# quite|orthographic representations --> prob = 0.0002698429005270054, entropy = 4.665206077661126, freq = 0.000269842900527, marginal prob = 0.9999999999999799
# volunteer|orthographic representations --> prob = 2.643076615419026e-05, entropy = 4.665206077661126, freq = 2.643076615418973e-05, marginal prob = 0.9999999999999799
# spirit|orthographic representations --> prob = 8.53810613462586e-05, entropy = 4.665206077661126, freq = 8.538106134625688e-05, marginal prob = 0.9999999999999799
# Overall conditional entropy H(L|O) = 4.6648 nats
# Sum of frequencies (should be ~1.0) = 1.0000

# %%
print("Entropy of EN word:", entropy([conditional_prob_ent_dict[word][2] for word in conditional_prob_ent_dict.keys()]))
# Out:
# Entropy of EN word: 4.665206077661126

# %% [markdown]
# #### Scale the SSIM score with an exp function and a temperature alph = 10.0.
# #### This result is the numbers reported in the paper

# %%
import os
import json
import numpy as np
import pandas as pd
from PIL import Image
from skimage.metrics import structural_similarity as ssim
from scipy.stats import entropy

# -----------------------------
# Configurations
# -----------------------------
visible = "whole"   # "upper" or "lower"
lang = "en"         # "en" or "zh"
resize_shape = (128, 128)

# Similarity transformation parameters
sim_method = "exp"   # options: "exp", "power", "minmax", "raw"
alpha = 10.0         # strength for exp scaling
beta = 2.0           # strength for power scaling

if lang == "en":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/EN"
elif lang == "zh":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/ZH"

# -----------------------------
# Similarity transformation
# -----------------------------
def transform_similarity(sim, method="exp", alpha=2.0, beta=2.0):
    """
    Transform similarity into a likelihood.
    """
    if method == "exp":
        return np.exp(alpha * sim)
    elif method == "power":
        return np.power(max(sim, 1e-6), beta)
    elif method == "minmax":
        # clip and rescale to [0,1]
        sim = np.clip(sim, 0.0, 1.0)
        return np.power(sim, beta)
    else:  # "raw"
        return max(sim, 1e-6)

# -----------------------------
# Load dataset
# -----------------------------
with open(jsonl_file_path, 'r') as file:
    lines = file.readlines()
print("total lines:", len(lines))

data_list = [json.loads(line) for line in lines]

# Preload images to memory
image_cache = {}
for data in data_list:
    label = data["label"]
    img_file = os.path.join(img_path, data["image"])
    img_array = np.array(Image.open(img_file).convert("L").resize(resize_shape))
    image_cache[label] = (img_array, data["normal_freq"])

# -----------------------------
# Bayesian baseline computation
# -----------------------------
results = {}
overall_entropy = 0.0
rows = []

for target_label, (target_img, p_target_prior) in image_cache.items():
    likelihoods = []
    
    for comp_label, (comp_img, p_comp_prior) in image_cache.items():
        similarity = ssim(target_img, comp_img)
        p_likelihood = transform_similarity(similarity, method=sim_method, alpha=alpha, beta=beta)
        likelihoods.append((comp_label, p_comp_prior, p_likelihood))
    
    # Marginal likelihood
    Z = sum(p_prior * p_like for _, p_prior, p_like in likelihoods)
    
    # Posterior distribution
    posteriors = {}
    for comp_label, p_prior, p_like in likelihoods:
        p_post = (p_prior * p_like) / Z if Z > 0 else 0
        posteriors[comp_label] = p_post
    
    # Entropy of posterior
    posterior_probs = list(posteriors.values())
    ent_cond = entropy(posterior_probs)  # in nats
    
    results[target_label] = {
        "posterior_entropy": ent_cond,
        "prior": p_target_prior,
        "posterior_target": posteriors[target_label],
        "marginal_likelihood": Z
    }
    
    overall_entropy += p_target_prior * ent_cond
    
    rows.append({
        "target": target_label,
        "prior": p_target_prior,
        "posterior_target": posteriors[target_label],
        "entropy": ent_cond,
        "marginal_likelihood": Z
    })

# -----------------------------
# Summarize results
# -----------------------------
print(f"Overall conditional entropy H(W|O) = {overall_entropy:.4f} nats")

df = pd.DataFrame(rows)
os.makedirs(out_path, exist_ok=True)
out_csv = f"{out_path}/bayesian_baseline_{lang}_{visible}_{sim_method}_{alpha}.csv"
df.to_csv(out_csv, index=False)
print(f"Results saved to {out_csv}")
