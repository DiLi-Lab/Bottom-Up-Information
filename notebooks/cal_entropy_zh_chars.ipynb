# %%
# Import
import numpy as np
import math
from PIL import Image, ImageDraw, ImageFont
import os
import json

# test perceptual similarity metrics on letters
from skimage.metrics import structural_similarity as ssim
import numpy as np
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt

# %%
def entropy(freqs):
    total = sum(freqs)
    if total == 0:
        return 0
    return -sum((f / total) * np.log(f / total) for f in freqs if f > 0)

# %% [markdown]
# ## Baseline - ZH conditional entropy
#
# ### As a sanity check, if threshold set to 0, i.e., score > 0.0, calculate the marginal prob etc., the conditional entropy should be the same as, or very similar to the unconditional entropy.

# %%
## note, this is the innitial version, which used the row ssim metric, not the scaled ssim metric
## the scaled ssim metric is more distinguishing between similar and dissimilar images

visible = "upper"
lang = "zh"
threshold = 0.2

if lang == "en":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/EN"
if lang == "zh":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/ZH"
# img_path = f"/swdata/yin/Cui/Re-Veil/create-dataset-new/dataset_en/en_word_{visible}_20250513/images"
# jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/en/en-word/{visible}/img_dict_test.json"

conditional_prob_ent_dict = {}

# pick a fixed size for all images (e.g., 28x28)
resize_shape = (128, 128)

with open(jsonl_file_path, 'r') as file:
    lines = file.readlines()
    print("total lines:", len(lines))

comparison_counter = 0  # keep track of comparisons
sum_freq = 0.0

for line in lines:
    p_marginal = 0
    p_similars = []
    data = json.loads(line)
    img = img_path + "/" + data["image"]
    target = data["label"]
    p_target = data["normal_freq"]

    img_target = np.array(Image.open(img).convert("L").resize(resize_shape))
    sum_freq += p_target   ## accumulate total frequency sum should be 1.0

    # compare img_target with all other images
    for comp_line in lines:
        comp_data = json.loads(comp_line)
        comp_img_path = img_path + "/" + comp_data["image"]
        comparison = comp_data["label"]
        p_comp = comp_data["normal_freq"]

        img_comp = np.array(Image.open(comp_img_path).convert("L").resize(resize_shape))

        similarity = ssim(img_target, img_comp)
        if similarity > threshold:  # threshold for considering similar
            p_similars.append(p_comp)
            p_marginal += p_comp

        # # Show the two images every 400th comparison for visual inspection
        # comparison_counter += 1
        # if comparison_counter % 400 == 0:
        #     print(f"[{comparison_counter}] {img} vs {comp_img_path}, SSIM = {similarity:.3f}")
        #     fig, axes = plt.subplots(1, 2, figsize=(4, 2))
        #     axes[0].imshow(img_target, cmap="gray")
        #     axes[0].set_title(f"Target: {target}")
        #     axes[0].axis("off")
        #     axes[1].imshow(img_comp, cmap="gray")
        #     axes[1].set_title(f"Comp: {comparison}")
        #     axes[1].axis("off")
        #     plt.show()

    p_target_given_orth = p_target / p_marginal if p_marginal > 0 else 0
    ent_cond = entropy(p_similars) if len(p_similars) > 0 else 0
    conditional_prob_ent_dict[target] = (p_target_given_orth, ent_cond, p_target, p_marginal)  
    print(f"{target}|orthographic representation --> prob = {p_target_given_orth}, entropy = {ent_cond}, freq = {p_target}, marginal prob = {p_marginal}") 

# compute overall conditional entropy
H_W_given_O = 0.0
rows = []
for word, (p_target_given_orth, ent_cond, freq_target, p_marginal) in conditional_prob_ent_dict.items():
    H_W_given_O += freq_target * ent_cond
    rows.append({
        "target": word,
        "prob_target": p_target_given_orth,
        "entropy": ent_cond,
        "freq": freq_target,
        "marginal": p_marginal
    })

print(f"Overall conditional entropy H(L|O) = {H_W_given_O:.4f} nats")
print(f"Sum of frequencies (should be ~1.0) = {sum_freq:.4f}")

# df = pd.DataFrame(rows, columns=["target", "prob_target", "entropy", "freq", "marginal"])
# out_csv = f"{out_path}/baseline_{lang}_word_{visible}_{threshold}.csv"
# df.to_csv(out_csv, index=False)
# print(f"Results saved to {out_csv}")
# Out:
# total lines: 936
# 一|orthographic representation --> prob = 0.005093671677352627, entropy = 4.677681635496143, freq = 0.0050936716773525, marginal prob = 0.9999999999999749
# 七|orthographic representation --> prob = 0.00017690924212740444, entropy = 4.677681635496143, freq = 0.0001769092421274, marginal prob = 0.9999999999999749
# 三|orthographic representation --> prob = 0.0026152991676729655, entropy = 4.677681635496143, freq = 0.0026152991676729, marginal prob = 0.9999999999999749
# 上|orthographic representation --> prob = 0.009721792717527945, entropy = 4.677681635496143, freq = 0.0097217927175277, marginal prob = 0.9999999999999749
# 下|orthographic representation --> prob = 0.0034505517814323867, entropy = 4.677681635496143, freq = 0.0034505517814323, marginal prob = 0.9999999999999749
# 不|orthographic representation --> prob = 0.015746565669235494, entropy = 4.677681635496143, freq = 0.0157465656692351, marginal prob = 0.9999999999999749
# 与|orthographic representation --> prob = 0.0119673899086189, entropy = 4.677681635496143, freq = 0.0119673899086186, marginal prob = 0.9999999999999749
# 专|orthographic representation --> prob = 0.0001282177768198966, entropy = 4.675946177171298, freq = 0.0001281633518817, marginal prob = 0.9995755273601956
# 且|orthographic representation --> prob = 0.0004436423718984111, entropy = 4.677681635496143, freq = 0.0004436423718984, marginal prob = 0.9999999999999749
# 世|orthographic representation --> prob = 0.00011427914051415278, entropy = 4.675117272799161, freq = 0.0001141968327664, marginal prob = 0.9992797657789299
# 丘|orthographic representation --> prob = 1.612996031161689e-05, entropy = 4.677681635496143, freq = 1.6129960311616486e-05, marginal prob = 0.9999999999999749
# 业|orthographic representation --> prob = 0.00016513354953990415, entropy = 4.677681635496143, freq = 0.0001651335495399, marginal prob = 0.9999999999999749
# 东|orthographic representation --> prob = 0.0004053029076603102, entropy = 4.677681635496143, freq = 0.0004053029076603, marginal prob = 0.9999999999999749
# 两|orthographic representation --> prob = 0.0012816335188177322, entropy = 4.677681635496143, freq = 0.0012816335188177, marginal prob = 0.9999999999999749
# 严|orthographic representation --> prob = 5.477066319734089e-05, entropy = 4.677681635496143, freq = 5.477066319733951e-05, marginal prob = 0.9999999999999749
# 个|orthographic representation --> prob = 0.006134314278102153, entropy = 4.677681635496143, freq = 0.006134314278102, marginal prob = 0.9999999999999749
# 中|orthographic representation --> prob = 0.012241243224605607, entropy = 4.677681635496143, freq = 0.0122412432246053, marginal prob = 0.9999999999999749
# 串|orthographic representation --> prob = 3.0123864758537482e-05, entropy = 4.677681635496143, freq = 3.0123864758536727e-05, marginal prob = 0.9999999999999749
# 临|orthographic representation --> prob = 7.202342210450324e-05, entropy = 4.677681635496143, freq = 7.202342210450144e-05, marginal prob = 0.9999999999999749
# 丹|orthographic representation --> prob = 4.874589024563338e-05, entropy = 4.677681635496143, freq = 4.874589024563216e-05, marginal prob = 0.9999999999999749
# 为|orthographic representation --> prob = 0.013418812483348436, entropy = 4.677681635496143, freq = 0.0134188124833481, marginal prob = 0.9999999999999749
# 主|orthographic representation --> prob = 0.0003861331755412097, entropy = 4.677681635496143, freq = 0.0003861331755412, marginal prob = 0.9999999999999749
# 久|orthographic representation --> prob = 0.00026152991676720657, entropy = 4.677681635496143, freq = 0.0002615299167672, marginal prob = 0.9999999999999749
# 么|orthographic representation --> prob = 0.00119673899086183, entropy = 4.677681635496143, freq = 0.0011967389908618, marginal prob = 0.9999999999999749
# 义|orthographic representation --> prob = 0.00018101704186720456, entropy = 4.677681635496143, freq = 0.0001810170418672, marginal prob = 0.9999999999999749
# 之|orthographic representation --> prob = 0.0034505517814323867, entropy = 4.677681635496143, freq = 0.0034505517814323, marginal prob = 0.9999999999999749
# 乎|orthographic representation --> prob = 2.440033045441536e-05, entropy = 4.677681635496143, freq = 2.4400330454414748e-05, marginal prob = 0.9999999999999749
# 乏|orthographic representation --> prob = 6.271240936095531e-06, entropy = 4.677681635496143, freq = 6.271240936095374e-06, marginal prob = 0.9999999999999749
# 乐|orthographic representation --> prob = 0.00016513354953990415, entropy = 4.677681635496143, freq = 0.0001651335495399, marginal prob = 0.9999999999999749
# 九|orthographic representation --> prob = 0.00016129960311610404, entropy = 4.677681635496143, freq = 0.0001612996031161, marginal prob = 0.9999999999999749
# 也|orthographic representation --> prob = 0.013720051130933844, entropy = 4.677681635496143, freq = 0.0137200511309335, marginal prob = 0.9999999999999749
# 习|orthographic representation --> prob = 5.586607646128769e-05, entropy = 4.677681635496143, freq = 5.586607646128629e-05, marginal prob = 0.9999999999999749
# 书|orthographic representation --> prob = 0.0006572479583680165, entropy = 4.677681635496143, freq = 0.000657247958368, marginal prob = 0.9999999999999749
# 乳|orthographic representation --> prob = 1.98269800774374e-05, entropy = 4.677681635496143, freq = 1.98269800774369e-05, marginal prob = 0.9999999999999749
# 了|orthographic representation --> prob = 0.03779175760616515, entropy = 4.677681635496143, freq = 0.0377917576061642, marginal prob = 0.9999999999999749
# 争|orthographic representation --> prob = 0.00010406426007490261, entropy = 4.677681635496143, freq = 0.0001040642600749, marginal prob = 0.9999999999999749
# 事|orthographic representation --> prob = 0.00168984775810981, entropy = 4.677035764036733, freq = 0.0016896749596379, marginal prob = 0.9998977431717853
# 二|orthographic representation --> prob = 0.0006709406241674168, entropy = 4.677681635496143, freq = 0.0006709406241674, marginal prob = 0.9999999999999749
# 于|orthographic representation --> prob = 0.00558660764612874, entropy = 4.677681635496143, freq = 0.0055866076461286, marginal prob = 0.9999999999999749
# 五|orthographic representation --> prob = 0.0003697019765820093, entropy = 4.677681635496143, freq = 0.000369701976582, marginal prob = 0.9999999999999749
# 亚|orthographic representation --> prob = 0.000279330382306407, entropy = 4.677681635496143, freq = 0.0002793303823064, marginal prob = 0.9999999999999749
# 些|orthographic representation --> prob = 0.00048745890245631223, entropy = 4.677681635496143, freq = 0.0004874589024563, marginal prob = 0.9999999999999749
# 亡|orthographic representation --> prob = 2.174395328934433e-05, entropy = 4.677681635496143, freq = 2.1743953289343784e-05, marginal prob = 0.9999999999999749
# 交|orthographic representation --> prob = 0.00019388814771850485, entropy = 4.677681635496143, freq = 0.0001938881477185, marginal prob = 0.9999999999999749
# 产|orthographic representation --> prob = 0.000238526238224406, entropy = 4.677681635496143, freq = 0.0002385262382244, marginal prob = 0.9999999999999749
# 享|orthographic representation --> prob = 1.6545770544478292e-05, entropy = 4.670923882824758, freq = 1.651335495399786e-05, marginal prob = 0.998040853377406
# 亲|orthographic representation --> prob = 0.00014705923068480367, entropy = 4.677681635496143, freq = 0.0001470592306848, marginal prob = 0.9999999999999749
# 人|orthographic representation --> prob = 0.015061932379268677, entropy = 4.677681635496143, freq = 0.0150619323792683, marginal prob = 0.9999999999999749
# 什|orthographic representation --> prob = 5.9973876201088264e-05, entropy = 4.677681635496143, freq = 5.997387620108676e-05, marginal prob = 0.9999999999999749
# 仅|orthographic representation --> prob = 0.0004053029076603102, entropy = 4.677681635496143, freq = 0.0004053029076603, marginal prob = 0.9999999999999749
# 今|orthographic representation --> prob = 0.00026152991676720657, entropy = 4.677681635496143, freq = 0.0002615299167672, marginal prob = 0.9999999999999749
# 仍|orthographic representation --> prob = 0.0007038030220858177, entropy = 4.677681635496143, freq = 0.0007038030220858, marginal prob = 0.9999999999999749
# 从|orthographic representation --> prob = 0.004874589024563322, entropy = 4.677681635496143, freq = 0.0048745890245632, marginal prob = 0.9999999999999749
# 他|orthographic representation --> prob = 0.01311757383576313, entropy = 4.677681635496143, freq = 0.0131175738357628, marginal prob = 0.9999999999999749
# 代|orthographic representation --> prob = 0.00013720051130930344, entropy = 4.677681635496143, freq = 0.0001372005113093, marginal prob = 0.9999999999999749
# 令|orthographic representation --> prob = 0.0003697019765820093, entropy = 4.677681635496143, freq = 0.000369701976582, marginal prob = 0.9999999999999749
# 以|orthographic representation --> prob = 0.00476504769816862, entropy = 4.677681635496143, freq = 0.0047650476981685, marginal prob = 0.9999999999999749
# 们|orthographic representation --> prob = 0.002078546668339052, entropy = 4.677681635496143, freq = 0.002078546668339, marginal prob = 0.9999999999999749
# 件|orthographic representation --> prob = 0.0003779175760616095, entropy = 4.677681635496143, freq = 0.0003779175760616, marginal prob = 0.9999999999999749
# 价|orthographic representation --> prob = 9.064544759159916e-05, entropy = 4.677681635496143, freq = 9.064544759159688e-05, marginal prob = 0.9999999999999749
# 任|orthographic representation --> prob = 0.00041351850713991034, entropy = 4.677681635496143, freq = 0.0004135185071399, marginal prob = 0.9999999999999749
# 仿|orthographic representation --> prob = 1.5746565669235504e-05, entropy = 4.677681635496143, freq = 1.5746565669235108e-05, marginal prob = 0.9999999999999749
# 企|orthographic representation --> prob = 2.3304917190468546e-05, entropy = 4.677681635496143, freq = 2.330491719046796e-05, marginal prob = 0.9999999999999749
# 休|orthographic representation --> prob = 3.0123864758537482e-05, entropy = 4.677681635496143, freq = 3.0123864758536727e-05, marginal prob = 0.9999999999999749
# 优|orthographic representation --> prob = 7.53096618963437e-05, entropy = 4.677681635496143, freq = 7.530966189634182e-05, marginal prob = 0.9999999999999749
# 会|orthographic representation --> prob = 0.008270370142798408, entropy = 4.677681635496143, freq = 0.0082703701427982, marginal prob = 0.9999999999999749
# 传|orthographic representation --> prob = 0.000279330382306407, entropy = 4.677681635496143, freq = 0.0002793303823064, marginal prob = 0.9999999999999749
# 伤|orthographic representation --> prob = 0.00013418812483340336, entropy = 4.677681635496143, freq = 0.0001341881248334, marginal prob = 0.9999999999999749
# 伯|orthographic representation --> prob = 4.436423718984611e-05, entropy = 4.677681635496143, freq = 4.4364237189845e-05, marginal prob = 0.9999999999999749
# 估|orthographic representation --> prob = 1.4048675110117937e-05, entropy = 4.677681635496143, freq = 1.4048675110117585e-05, marginal prob = 0.9999999999999749
# 似|orthographic representation --> prob = 5.2305983353460544e-05, entropy = 4.677681635496143, freq = 5.230598335345923e-05, marginal prob = 0.9999999999999749
# 但|orthographic representation --> prob = 0.005723534304122044, entropy = 4.677681635496143, freq = 0.0057235343041219, marginal prob = 0.9999999999999749
# 位|orthographic representation --> prob = 0.0007886975500416199, entropy = 4.677681635496143, freq = 0.0007886975500416, marginal prob = 0.9999999999999749
# 低|orthographic representation --> prob = 0.0004436423718984111, entropy = 4.677681635496143, freq = 0.0004436423718984, marginal prob = 0.9999999999999749
# 住|orthographic representation --> prob = 0.0006709406241674168, entropy = 4.677681635496143, freq = 0.0006709406241674, marginal prob = 0.9999999999999749
# 体|orthographic representation --> prob = 0.0002738533159866069, entropy = 4.677681635496143, freq = 0.0002738533159866, marginal prob = 0.9999999999999749
# 何|orthographic representation --> prob = 0.00010406426007490261, entropy = 4.677681635496143, freq = 0.0001040642600749, marginal prob = 0.9999999999999749
# 余|orthographic representation --> prob = 0.00011693536592630292, entropy = 4.677681635496143, freq = 0.0001169353659263, marginal prob = 0.9999999999999749
# 佛|orthographic representation --> prob = 5.477066319734089e-05, entropy = 4.677681635496143, freq = 5.477066319733951e-05, marginal prob = 0.9999999999999749
# 作|orthographic representation --> prob = 0.0007886975500416199, entropy = 4.677681635496143, freq = 0.0007886975500416, marginal prob = 0.9999999999999749
# 你|orthographic representation --> prob = 0.013720288219493275, entropy = 4.677555691098229, freq = 0.0137200511309335, marginal prob = 0.9999827198557362
# 使|orthographic representation --> prob = 0.0013720051130933345, entropy = 4.677681635496143, freq = 0.0013720051130933, marginal prob = 0.9999999999999749
# 侈|orthographic representation --> prob = 8.270370142798472e-07, entropy = 4.677681635496143, freq = 8.270370142798264e-07, marginal prob = 0.9999999999999749
# 例|orthographic representation --> prob = 0.00011693536592630292, entropy = 4.677681635496143, freq = 0.0001169353659263, marginal prob = 0.9999999999999749
# 供|orthographic representation --> prob = 0.00018950649466270474, entropy = 4.677681635496143, freq = 0.0001895064946627, marginal prob = 0.9999999999999749
# 依|orthographic representation --> prob = 0.00013418812483340336, entropy = 4.677681635496143, freq = 0.0001341881248334, marginal prob = 0.9999999999999749
# 促|orthographic representation --> prob = 3.0123864758537482e-05, entropy = 4.677681635496143, freq = 3.0123864758536727e-05, marginal prob = 0.9999999999999749
# 保|orthographic representation --> prob = 0.00011693536592630292, entropy = 4.677681635496143, freq = 0.0001169353659263, marginal prob = 0.9999999999999749
# 信|orthographic representation --> prob = 0.00037792968524541867, entropy = 4.677467890573551, freq = 0.0003779175760616, marginal prob = 0.9999679591620044
# 俱|orthographic representation --> prob = 2.2264274589719068e-05, entropy = 4.677681635496143, freq = 2.226427458971851e-05, marginal prob = 0.9999999999999749
# 值|orthographic representation --> prob = 0.0002675546897190067, entropy = 4.677681635496143, freq = 0.000267554689719, marginal prob = 0.9999999999999749
# 假|orthographic representation --> prob = 0.00030123864758530754, entropy = 4.677681635496143, freq = 0.0003012386475853, marginal prob = 0.9999999999999749
# 做|orthographic representation --> prob = 0.0032862397918403826, entropy = 4.677681635496143, freq = 0.0032862397918403, marginal prob = 0.9999999999999749
# 健|orthographic representation --> prob = 3.0123864758537482e-05, entropy = 4.677681635496143, freq = 3.0123864758536727e-05, marginal prob = 0.9999999999999749
# 偶|orthographic representation --> prob = 1.7280144238761045e-05, entropy = 4.677681635496143, freq = 1.728014423876061e-05, marginal prob = 0.9999999999999749
# 偷|orthographic representation --> prob = 9.283627411949279e-05, entropy = 4.677681635496143, freq = 9.283627411949046e-05, marginal prob = 0.9999999999999749
# 像|orthographic representation --> prob = 0.0013720051130933345, entropy = 4.677681635496143, freq = 0.0013720051130933, marginal prob = 0.9999999999999749
# 儿|orthographic representation --> prob = 0.00018101704186720456, entropy = 4.677681635496143, freq = 0.0001810170418672, marginal prob = 0.9999999999999749
# 充|orthographic representation --> prob = 4.053029076603225e-05, entropy = 4.677681635496143, freq = 4.0530290766031234e-05, marginal prob = 0.9999999999999749
# 先|orthographic representation --> prob = 0.0006873718231266172, entropy = 4.677681635496143, freq = 0.0006873718231266, marginal prob = 0.9999999999999749
# 光|orthographic representation --> prob = 0.0002555051438155064, entropy = 4.677681635496143, freq = 0.0002555051438155, marginal prob = 0.9999999999999749
# 克|orthographic representation --> prob = 0.00024400330454410612, entropy = 4.677681635496143, freq = 0.0002440033045441, marginal prob = 0.9999999999999749
# 免|orthographic representation --> prob = 5.8604609621154735e-05, entropy = 4.677681635496143, freq = 5.8604609621153264e-05, marginal prob = 0.9999999999999749
# 入|orthographic representation --> prob = 0.00032862397918400824, entropy = 4.677681635496143, freq = 0.000328623979184, marginal prob = 0.9999999999999749
# 全|orthographic representation --> prob = 0.000558660764612814, entropy = 4.677681635496143, freq = 0.0005586607646128, marginal prob = 0.9999999999999749
# 八|orthographic representation --> prob = 0.00014705923068480367, entropy = 4.677681635496143, freq = 0.0001470592306848, marginal prob = 0.9999999999999749
# 公|orthographic representation --> prob = 0.0001437729908930036, entropy = 4.677681635496143, freq = 0.000143772990893, marginal prob = 0.9999999999999749
# 六|orthographic representation --> prob = 0.0002555051438155064, entropy = 4.677681635496143, freq = 0.0002555051438155, marginal prob = 0.9999999999999749
# 兰|orthographic representation --> prob = 7.53096618963437e-05, entropy = 4.677681635496143, freq = 7.530966189634182e-05, marginal prob = 0.9999999999999749
# 关|orthographic representation --> prob = 0.0003779175760616095, entropy = 4.677681635496143, freq = 0.0003779175760616, marginal prob = 0.9999999999999749
# 兴|orthographic representation --> prob = 5.723534304122122e-05, entropy = 4.677681635496143, freq = 5.723534304121978e-05, marginal prob = 0.9999999999999749
# 其|orthographic representation --> prob = 0.0025066859457201873, entropy = 4.669140501467817, freq = 0.0024975422417986, marginal prob = 0.9963522738310322
# 具|orthographic representation --> prob = 0.00015395792443337068, entropy = 4.675937586559963, freq = 0.0001539055635845, marginal prob = 0.9996599015668509
# 典|orthographic representation --> prob = 2.8754598178603963e-05, entropy = 4.677681635496143, freq = 2.875459817860324e-05, marginal prob = 0.9999999999999749
# 养|orthographic representation --> prob = 0.0001256909222432075, entropy = 4.66850767869933, freq = 0.0001251509654059, marginal prob = 0.9957040904174232
# 内|orthographic representation --> prob = 0.002078546668339052, entropy = 4.677681635496143, freq = 0.002078546668339, marginal prob = 0.9999999999999749
# 再|orthographic representation --> prob = 0.0021262645544007316, entropy = 4.675303738362967, freq = 0.0021251017320567, marginal prob = 0.9994531149279496
# 农|orthographic representation --> prob = 7.366654200042347e-05, entropy = 4.677681635496143, freq = 7.366654200042163e-05, marginal prob = 0.9999999999999749
# 况|orthographic representation --> prob = 1.7280144238761045e-05, entropy = 4.677681635496143, freq = 1.728014423876061e-05, marginal prob = 0.9999999999999749
# 冷|orthographic representation --> prob = 0.00011693536592630292, entropy = 4.677681635496143, freq = 0.0001169353659263, marginal prob = 0.9999999999999749
# 准|orthographic representation --> prob = 0.00013117573835760328, entropy = 4.677681635496143, freq = 0.0001311757383576, marginal prob = 0.9999999999999749
# 凌|orthographic representation --> prob = 1.2515096540592389e-05, entropy = 4.677681635496143, freq = 1.2515096540592076e-05, marginal prob = 0.9999999999999749
# 减|orthographic representation --> prob = 6.8742997508939e-05, entropy = 4.677178476560125, freq = 6.873718231266108e-05, marginal prob = 0.9999154067106666
# 几|orthographic representation --> prob = 0.0003368395786636085, entropy = 4.677681635496143, freq = 0.0003368395786636, marginal prob = 0.9999999999999749
# 凡|orthographic representation --> prob = 7.722663510825064e-05, entropy = 4.677681635496143, freq = 7.72266351082487e-05, marginal prob = 0.9999999999999749
# 凯|orthographic representation --> prob = 2.3852623822441957e-05, entropy = 4.677681635496143, freq = 2.3852623822441357e-05, marginal prob = 0.9999999999999749
# 出|orthographic representation --> prob = 0.0022784595890093574, entropy = 4.677681635496143, freq = 0.0022784595890093, marginal prob = 0.9999999999999749
# 分|orthographic representation --> prob = 0.0010652893991882266, entropy = 4.677681635496143, freq = 0.0010652893991882, marginal prob = 0.9999999999999749
# 切|orthographic representation --> prob = 7.53096618963437e-05, entropy = 4.677681635496143, freq = 7.530966189634182e-05, marginal prob = 0.9999999999999749
# 划|orthographic representation --> prob = 7.722663510825064e-05, entropy = 4.677681635496143, freq = 7.72266351082487e-05, marginal prob = 0.9999999999999749
# 列|orthographic representation --> prob = 0.000119673899086103, entropy = 4.677681635496143, freq = 0.0001196738990861, marginal prob = 0.9999999999999749
# 则|orthographic representation --> prob = 0.0014705923068485368, entropy = 4.677681635496143, freq = 0.0014705923068485, marginal prob = 0.9999999999999749
# 刚|orthographic representation --> prob = 0.00036148637710240903, entropy = 4.677681635496143, freq = 0.0003614863771024, marginal prob = 0.9999999999999749
# 初|orthographic representation --> prob = 0.00024400330454410612, entropy = 4.677681635496143, freq = 0.0002440033045441, marginal prob = 0.9999999999999749
# 利|orthographic representation --> prob = 0.00013720051130930344, entropy = 4.677681635496143, freq = 0.0001372005113093, marginal prob = 0.9999999999999749
# 到|orthographic representation --> prob = 0.008270370142798408, entropy = 4.677681635496143, freq = 0.0082703701427982, marginal prob = 0.9999999999999749
# 制|orthographic representation --> prob = 0.0007203164789054985, entropy = 4.677064919500531, freq = 0.000720234221045, marginal prob = 0.9998858031672084
# 前|orthographic representation --> prob = 0.0023304917190467584, entropy = 4.677681635496143, freq = 0.0023304917190467, marginal prob = 0.9999999999999749
# 剧|orthographic representation --> prob = 0.00010652893991880267, entropy = 4.677681635496143, freq = 0.0001065289399188, marginal prob = 0.9999999999999749
# 剩|orthographic representation --> prob = 7.447830803912207e-05, entropy = 4.668470465105541, freq = 7.366654200042163e-05, marginal prob = 0.9891006380237044
# 力|orthographic representation --> prob = 0.0002078546668339052, entropy = 4.677681635496143, freq = 0.0002078546668339, marginal prob = 0.9999999999999749
# 劝|orthographic representation --> prob = 5.477066319734089e-05, entropy = 4.677681635496143, freq = 5.477066319733951e-05, marginal prob = 0.9999999999999749
# 功|orthographic representation --> prob = 4.135185071399236e-05, entropy = 4.677681635496143, freq = 4.135185071399132e-05, marginal prob = 0.9999999999999749
# 加|orthographic representation --> prob = 0.0004545965045379114, entropy = 4.677681635496143, freq = 0.0004545965045379, marginal prob = 0.9999999999999749
# 务|orthographic representation --> prob = 4.874589024563338e-05, entropy = 4.677681635496143, freq = 4.874589024563216e-05, marginal prob = 0.9999999999999749
# 动|orthographic representation --> prob = 0.0004053029076603102, entropy = 4.677681635496143, freq = 0.0004053029076603, marginal prob = 0.9999999999999749
# 助|orthographic representation --> prob = 6.572479583680906e-05, entropy = 4.677681635496143, freq = 6.572479583680741e-05, marginal prob = 0.9999999999999749
# 励|orthographic representation --> prob = 5.997387620108827e-06, entropy = 4.677681635496143, freq = 5.997387620108676e-06, marginal prob = 0.9999999999999749
# 劳|orthographic representation --> prob = 3.708699622250356e-05, entropy = 4.671106221232922, freq = 3.697019765820416e-05, marginal prob = 0.9968506868661278
# 包|orthographic representation --> prob = 0.00024975422417980626, entropy = 4.677681635496143, freq = 0.0002497542241798, marginal prob = 0.9999999999999749
# 化|orthographic representation --> prob = 0.00024975422417980626, entropy = 4.677681635496143, freq = 0.0002497542241798, marginal prob = 0.9999999999999749
# 北|orthographic representation --> prob = 0.00026152991676720657, entropy = 4.677681635496143, freq = 0.0002615299167672, marginal prob = 0.9999999999999749
# 匪|orthographic representation --> prob = 1.3418870545223205e-05, entropy = 4.67764410837158, freq = 1.3418812483348178e-05, marginal prob = 0.9999956731175823
# 区|orthographic representation --> prob = 0.00119673899086183, entropy = 4.677681635496143, freq = 0.0011967389908618, marginal prob = 0.9999999999999749
# 十|orthographic representation --> prob = 0.00015061932379260376, entropy = 4.677681635496143, freq = 0.0001506193237926, marginal prob = 0.9999999999999749
# 千|orthographic representation --> prob = 9.064544759159916e-05, entropy = 4.677681635496143, freq = 9.064544759159688e-05, marginal prob = 0.9999999999999749
# 升|orthographic representation --> prob = 0.00011693536592630292, entropy = 4.677681635496143, freq = 0.0001169353659263, marginal prob = 0.9999999999999749
# 午|orthographic representation --> prob = 6.271240936095531e-06, entropy = 4.677681635496143, freq = 6.271240936095374e-06, marginal prob = 0.9999999999999749
# 半|orthographic representation --> prob = 0.0002555051438155064, entropy = 4.677681635496143, freq = 0.0002555051438155, marginal prob = 0.9999999999999749
# 单|orthographic representation --> prob = 0.0002675546897190067, entropy = 4.677681635496143, freq = 0.000267554689719, marginal prob = 0.9999999999999749
# 南|orthographic representation --> prob = 0.00031600022717943866, entropy = 4.669856311213467, freq = 0.0003149313133847, marginal prob = 0.9966173638409073
# 博|orthographic representation --> prob = 5.2305983353460544e-05, entropy = 4.677681635496143, freq = 5.230598335345923e-05, marginal prob = 0.9999999999999749
# 卡|orthographic representation --> prob = 0.0002738533159866069, entropy = 4.677681635496143, freq = 0.0002738533159866, marginal prob = 0.9999999999999749
# 卢|orthographic representation --> prob = 3.614863771024499e-05, entropy = 4.677681635496143, freq = 3.614863771024408e-05, marginal prob = 0.9999999999999749
# 印|orthographic representation --> prob = 7.722663510825064e-05, entropy = 4.677681635496143, freq = 7.72266351082487e-05, marginal prob = 0.9999999999999749
# 却|orthographic representation --> prob = 0.002078546668339052, entropy = 4.677681635496143, freq = 0.002078546668339, marginal prob = 0.9999999999999749
# 历|orthographic representation --> prob = 8.270370142798472e-05, entropy = 4.677681635496143, freq = 8.270370142798264e-05, marginal prob = 0.9999999999999749
# 压|orthographic representation --> prob = 0.000119673899086103, entropy = 4.677681635496143, freq = 0.0001196738990861, marginal prob = 0.9999999999999749
# 原|orthographic representation --> prob = 0.0004998031146460602, entropy = 4.6704955904006065, freq = 0.0004984130350957, marginal prob = 0.9972187457228141
# 去|orthographic representation --> prob = 0.0039708730818072, entropy = 4.677681635496143, freq = 0.0039708730818071, marginal prob = 0.9999999999999749
# 参|orthographic representation --> prob = 0.00011145829960650279, entropy = 4.677681635496143, freq = 0.0001114582996065, marginal prob = 0.9999999999999749
# 叉|orthographic representation --> prob = 2.440033045441536e-05, entropy = 4.677681635496143, freq = 2.4400330454414748e-05, marginal prob = 0.9999999999999749
# 及|orthographic representation --> prob = 0.0032862397918403826, entropy = 4.677681635496143, freq = 0.0032862397918403, marginal prob = 0.9999999999999749
# 友|orthographic representation --> prob = 3.861331755412532e-05, entropy = 4.677681635496143, freq = 3.861331755412435e-05, marginal prob = 0.9999999999999749
# 发|orthographic representation --> prob = 0.0009064577526372127, entropy = 4.677649633812278, freq = 0.0009064544759159, marginal prob = 0.9999963851362039
# 取|orthographic representation --> prob = 0.00022264274589710558, entropy = 4.677681635496143, freq = 0.0002226427458971, marginal prob = 0.9999999999999749
# 受|orthographic representation --> prob = 0.0008464828346470732, entropy = 4.675835377385239, freq = 0.0008462067463988, marginal prob = 0.9996738407006348
# 变|orthographic representation --> prob = 0.000558660764612814, entropy = 4.677681635496143, freq = 0.0005586607646128, marginal prob = 0.9999999999999749
# 口|orthographic representation --> prob = 0.0002278459589009057, entropy = 4.677681635496143, freq = 0.0002278459589009, marginal prob = 0.9999999999999749
# 古|orthographic representation --> prob = 0.00013720051130930344, entropy = 4.677681635496143, freq = 0.0001372005113093, marginal prob = 0.9999999999999749
# 另|orthographic representation --> prob = 0.0009503363299153916, entropy = 4.677275542384225, freq = 0.0009502710064738, marginal prob = 0.9999312628176622
# 只|orthographic representation --> prob = 0.00238526238224416, entropy = 4.677681635496143, freq = 0.0023852623822441, marginal prob = 0.9999999999999749
# 叫|orthographic representation --> prob = 0.001040642600749426, entropy = 4.677681635496143, freq = 0.0010406426007494, marginal prob = 0.9999999999999749
# 可|orthographic representation --> prob = 0.0026152991676729655, entropy = 4.677681635496143, freq = 0.0026152991676729, marginal prob = 0.9999999999999749
# 史|orthographic representation --> prob = 0.00026152991676720657, entropy = 4.677681635496143, freq = 0.0002615299167672, marginal prob = 0.9999999999999749
# 司|orthographic representation --> prob = 9.940875370317369e-05, entropy = 4.677681635496143, freq = 9.94087537031712e-05, marginal prob = 0.9999999999999749
# 叹|orthographic representation --> prob = 1.5061932379268741e-05, entropy = 4.677681635496143, freq = 1.5061932379268363e-05, marginal prob = 0.9999999999999749
# 吁|orthographic representation --> prob = 8.07867282160778e-06, entropy = 4.677681635496143, freq = 8.078672821607577e-06, marginal prob = 0.9999999999999749
# 吃|orthographic representation --> prob = 0.0012241243224605308, entropy = 4.677681635496143, freq = 0.0012241243224605, marginal prob = 0.9999999999999749
# 合|orthographic representation --> prob = 0.0002278459589009057, entropy = 4.677681635496143, freq = 0.0002278459589009, marginal prob = 0.9999999999999749
# 同|orthographic representation --> prob = 0.0007038030220858177, entropy = 4.677681635496143, freq = 0.0007038030220858, marginal prob = 0.9999999999999749
# 名|orthographic representation --> prob = 0.0009064544759159228, entropy = 4.677681635496143, freq = 0.0009064544759159, marginal prob = 0.9999999999999749
# 后|orthographic representation --> prob = 0.005860460962115448, entropy = 4.677681635496143, freq = 0.0058604609621153, marginal prob = 0.9999999999999749
# 向|orthographic representation --> prob = 0.00238526238224416, entropy = 4.677681635496143, freq = 0.0023852623822441, marginal prob = 0.9999999999999749
# 否|orthographic representation --> prob = 2.125101732056826e-05, entropy = 4.677681635496143, freq = 2.1251017320567727e-05, marginal prob = 0.9999999999999749
# 含|orthographic representation --> prob = 0.00012816335188170323, entropy = 4.677681635496143, freq = 0.0001281633518817, marginal prob = 0.9999999999999749
# 吻|orthographic representation --> prob = 0.00010652893991880267, entropy = 4.677681635496143, freq = 0.0001065289399188, marginal prob = 0.9999999999999749
# 呈|orthographic representation --> prob = 0.000119673899086103, entropy = 4.677681635496143, freq = 0.0001196738990861, marginal prob = 0.9999999999999749
# 告|orthographic representation --> prob = 6.271240936095531e-05, entropy = 4.677681635496143, freq = 6.271240936095374e-05, marginal prob = 0.9999999999999749
# 员|orthographic representation --> prob = 0.0003368395786636085, entropy = 4.677681635496143, freq = 0.0003368395786636, marginal prob = 0.9999999999999749
# 呢|orthographic representation --> prob = 0.0015746565669235394, entropy = 4.677681635496143, freq = 0.0015746565669235, marginal prob = 0.9999999999999749
# 周|orthographic representation --> prob = 0.0002675546897190067, entropy = 4.677681635496143, freq = 0.000267554689719, marginal prob = 0.9999999999999749
# 味|orthographic representation --> prob = 6.134314278102179e-05, entropy = 4.677681635496143, freq = 6.134314278102024e-05, marginal prob = 0.9999999999999749
# 呼|orthographic representation --> prob = 2.9302304810577367e-05, entropy = 4.677681635496143, freq = 2.9302304810576632e-05, marginal prob = 0.9999999999999749
# 命|orthographic representation --> prob = 0.00015746565669230397, entropy = 4.677681635496143, freq = 0.0001574656566923, marginal prob = 0.9999999999999749
# 和|orthographic representation --> prob = 0.019826980077437398, entropy = 4.677681635496143, freq = 0.0198269800774369, marginal prob = 0.9999999999999749
# 品|orthographic representation --> prob = 8.462067463989165e-05, entropy = 4.677681635496143, freq = 8.462067463988953e-05, marginal prob = 0.9999999999999749
# 响|orthographic representation --> prob = 8.270370142798472e-05, entropy = 4.677681635496143, freq = 8.270370142798264e-05, marginal prob = 0.9999999999999749
# 唯|orthographic representation --> prob = 3.861331755412532e-05, entropy = 4.677681635496143, freq = 3.861331755412435e-05, marginal prob = 0.9999999999999749
# 商|orthographic representation --> prob = 0.00010187343354700256, entropy = 4.677681635496143, freq = 0.000101873433547, marginal prob = 0.9999999999999749
# 善|orthographic representation --> prob = 6.891082425667447e-05, entropy = 4.6683758948865215, freq = 6.873718231266108e-05, marginal prob = 0.9974801934835865
# 喜|orthographic representation --> prob = 4.4386420737365376e-05, entropy = 4.675485528090482, freq = 4.4364237189845e-05, marginal prob = 0.9995002176982992
# 喻|orthographic representation --> prob = 5.586625546145163e-06, entropy = 4.677652883874826, freq = 5.58660764612863e-06, marginal prob = 0.9999967959161777
# 器|orthographic representation --> prob = 0.00015066677347745847, entropy = 4.676300126811816, freq = 0.0001506193237926, marginal prob = 0.9996850686865901
# 四|orthographic representation --> prob = 0.00041351850713991034, entropy = 4.677681635496143, freq = 0.0004135185071399, marginal prob = 0.9999999999999749
# 回|orthographic representation --> prob = 0.0006572479583680165, entropy = 4.677681635496143, freq = 0.000657247958368, marginal prob = 0.9999999999999749
# 因|orthographic representation --> prob = 0.0011146014018744094, entropy = 4.677560530310576, freq = 0.0011145829960658, marginal prob = 0.9999834866450208
# 团|orthographic representation --> prob = 0.0003368395786636085, entropy = 4.677681635496143, freq = 0.0003368395786636, marginal prob = 0.9999999999999749
# 困|orthographic representation --> prob = 4.874589024563338e-05, entropy = 4.677681635496143, freq = 4.874589024563216e-05, marginal prob = 0.9999999999999749
# 固|orthographic representation --> prob = 1.691843282697658e-05, entropy = 4.673855801884194, freq = 1.6896749596379236e-05, marginal prob = 0.9987183664811572
# 国|orthographic representation --> prob = 0.0012515096540592315, entropy = 4.677681635496143, freq = 0.0012515096540592, marginal prob = 0.9999999999999749
# 图|orthographic representation --> prob = 0.001040642600749426, entropy = 4.677681635496143, freq = 0.0010406426007494, marginal prob = 0.9999999999999749
# 土|orthographic representation --> prob = 7.886975500417086e-05, entropy = 4.677681635496143, freq = 7.886975500416888e-05, marginal prob = 0.9999999999999749
# 在|orthographic representation --> prob = 0.0397087308180721, entropy = 4.677681635496143, freq = 0.0397087308180711, marginal prob = 0.9999999999999749
# 地|orthographic representation --> prob = 0.0032862397918403826, entropy = 4.677681635496143, freq = 0.0032862397918403, marginal prob = 0.9999999999999749
# 场|orthographic representation --> prob = 0.00048745890245631223, entropy = 4.677681635496143, freq = 0.0004874589024563, marginal prob = 0.9999999999999749
# 圾|orthographic representation --> prob = 8.078672821607779e-07, entropy = 4.677681635496143, freq = 8.078672821607577e-07, marginal prob = 0.9999999999999749
# 址|orthographic representation --> prob = 1.196738990861898e-05, entropy = 4.677681635496143, freq = 1.196738990861868e-05, marginal prob = 0.9999999999999749
# 均|orthographic representation --> prob = 0.0005723534304121143, entropy = 4.677681635496143, freq = 0.0005723534304121, marginal prob = 0.9999999999999749
# 坎|orthographic representation --> prob = 1.8950649466279943e-05, entropy = 4.677681635496143, freq = 1.895064946627947e-05, marginal prob = 0.9999999999999749
# 坚|orthographic representation --> prob = 1.98269800774374e-05, entropy = 4.677681635496143, freq = 1.98269800774369e-05, marginal prob = 0.9999999999999749
# 坦|orthographic representation --> prob = 3.532707776228487e-05, entropy = 4.677681635496143, freq = 3.532707776228398e-05, marginal prob = 0.9999999999999749
# 垃|orthographic representation --> prob = 4.98413035095802e-07, entropy = 4.677681635496143, freq = 4.984130350957895e-07, marginal prob = 0.9999999999999749
# 型|orthographic representation --> prob = 0.00047650476981681196, entropy = 4.677681635496143, freq = 0.0004765047698168, marginal prob = 0.9999999999999749
# 埃|orthographic representation --> prob = 7.038030220858303e-05, entropy = 4.677681635496143, freq = 7.038030220858127e-05, marginal prob = 0.9999999999999749
# 城|orthographic representation --> prob = 0.00034505517814320866, entropy = 4.677681635496143, freq = 0.0003450551781432, marginal prob = 0.9999999999999749
# 域|orthographic representation --> prob = 3.149313133847101e-05, entropy = 4.677681635496143, freq = 3.1493131338470215e-05, marginal prob = 0.9999999999999749
# 基|orthographic representation --> prob = 0.00015391770303603314, entropy = 4.67722652177241, freq = 0.0001539055635845, marginal prob = 0.9999211302449706
# 堪|orthographic representation --> prob = 7.5309661896343705e-06, entropy = 4.677681635496143, freq = 7.530966189634182e-06, marginal prob = 0.9999999999999749
# 塑|orthographic representation --> prob = 6.271240936095531e-06, entropy = 4.677681635496143, freq = 6.271240936095374e-06, marginal prob = 0.9999999999999749
# 塔|orthographic representation --> prob = 0.00013117573835760328, entropy = 4.677681635496143, freq = 0.0001311757383576, marginal prob = 0.9999999999999749
# 塞|orthographic representation --> prob = 9.064544759159916e-05, entropy = 4.677681635496143, freq = 9.064544759159688e-05, marginal prob = 0.9999999999999749
# 境|orthographic representation --> prob = 5.608879795929518e-05, entropy = 4.67030982320396, freq = 5.586607646128629e-05, marginal prob = 0.9960291269181678
# 增|orthographic representation --> prob = 6.709406241674257e-05, entropy = 4.677681635496143, freq = 6.709406241674089e-05, marginal prob = 0.9999999999999749
# 墨|orthographic representation --> prob = 1.612996031161689e-05, entropy = 4.677681635496143, freq = 1.6129960311616486e-05, marginal prob = 0.9999999999999749
# 壁|orthographic representation --> prob = 1.689674959637966e-05, entropy = 4.677681635496143, freq = 1.6896749596379236e-05, marginal prob = 0.9999999999999749
# 士|orthographic representation --> prob = 7.204709850870384e-05, entropy = 4.6762540344299754, freq = 7.202342210450144e-05, marginal prob = 0.9996713760207909
# 处|orthographic representation --> prob = 0.0008270370142798207, entropy = 4.677681635496143, freq = 0.0008270370142798, marginal prob = 0.9999999999999749
# 备|orthographic representation --> prob = 7.886975500417086e-05, entropy = 4.677681635496143, freq = 7.886975500416888e-05, marginal prob = 0.9999999999999749
# 复|orthographic representation --> prob = 0.00021261346418208983, entropy = 4.675576550810298, freq = 0.0002125101732056, marginal prob = 0.9995141842174146
# 夏|orthographic representation --> prob = 7.216318797845541e-05, entropy = 4.670490826532994, freq = 7.202342210450144e-05, marginal prob = 0.9980631970694575
# 外|orthographic representation --> prob = 0.0007722663510824194, entropy = 4.677681635496143, freq = 0.0007722663510824, marginal prob = 0.9999999999999749
# 多|orthographic representation --> prob = 0.004436423718984611, entropy = 4.677681635496143, freq = 0.0044364237189845, marginal prob = 0.9999999999999749
# 夜|orthographic representation --> prob = 9.721792717528006e-05, entropy = 4.677681635496143, freq = 9.721792717527762e-05, marginal prob = 0.9999999999999749
# 够|orthographic representation --> prob = 0.00019388814771850485, entropy = 4.677681635496143, freq = 0.0001938881477185, marginal prob = 0.9999999999999749
# 大|orthographic representation --> prob = 0.0046555063717739174, entropy = 4.677681635496143, freq = 0.0046555063717738, marginal prob = 0.9999999999999749
# 天|orthographic representation --> prob = 0.0009721792717527244, entropy = 4.677681635496143, freq = 0.0009721792717527, marginal prob = 0.9999999999999749
# 太|orthographic representation --> prob = 0.00119673899086183, entropy = 4.677681635496143, freq = 0.0011967389908618, marginal prob = 0.9999999999999749
# 夫|orthographic representation --> prob = 0.00010652893991880267, entropy = 4.677681635496143, freq = 0.0001065289399188, marginal prob = 0.9999999999999749
# 失|orthographic representation --> prob = 7.038030220858303e-05, entropy = 4.677681635496143, freq = 7.038030220858127e-05, marginal prob = 0.9999999999999749
# 头|orthographic representation --> prob = 0.000320408379704408, entropy = 4.677681635496143, freq = 0.0003204083797044, marginal prob = 0.9999999999999749
# 夷|orthographic representation --> prob = 9.721792717528003e-06, entropy = 4.677681635496143, freq = 9.72179271752776e-06, marginal prob = 0.9999999999999749
# 奇|orthographic representation --> prob = 0.00010408064920267826, entropy = 4.676881813474014, freq = 0.0001040642600749, marginal prob = 0.9998425343432826
# 奉|orthographic representation --> prob = 3.3695861629605204e-05, entropy = 4.67617248867313, freq = 3.36839578663638e-05, marginal prob = 0.9996467292223521
# 奋|orthographic representation --> prob = 5.723534304122122e-06, entropy = 4.677681635496143, freq = 5.723534304121978e-06, marginal prob = 0.9999999999999749
# 奏|orthographic representation --> prob = 2.499653358103865e-05, entropy = 4.674412072077055, freq = 2.4975422417986817e-05, marginal prob = 0.9991554363734719
# 奢|orthographic representation --> prob = 1.5390556358452784e-06, entropy = 4.677681635496143, freq = 1.53905563584524e-06, marginal prob = 0.9999999999999749
# 女|orthographic representation --> prob = 0.0008270370142798207, entropy = 4.677681635496143, freq = 0.0008270370142798, marginal prob = 0.9999999999999749
# 她|orthographic representation --> prob = 0.0046555063717739174, entropy = 4.677681635496143, freq = 0.0046555063717738, marginal prob = 0.9999999999999749
# 好|orthographic representation --> prob = 0.00476504769816862, entropy = 4.677681635496143, freq = 0.0047650476981685, marginal prob = 0.9999999999999749
# 如|orthographic representation --> prob = 0.0012515096540592315, entropy = 4.677681635496143, freq = 0.0012515096540592, marginal prob = 0.9999999999999749
# 妻|orthographic representation --> prob = 3.781337951300622e-05, entropy = 4.675063049366921, freq = 3.779175760616426e-05, marginal prob = 0.9994281942761947
# 始|orthographic representation --> prob = 6.134314278102179e-05, entropy = 4.677681635496143, freq = 6.134314278102024e-05, marginal prob = 0.9999999999999749
# 子|orthographic representation --> prob = 0.0003861331755412097, entropy = 4.677681635496143, freq = 0.0003861331755412, marginal prob = 0.9999999999999749
# 孔|orthographic representation --> prob = 3.450551781432475e-05, entropy = 4.677681635496143, freq = 3.4505517814323886e-05, marginal prob = 0.9999999999999749
# 字|orthographic representation --> prob = 0.0004053029076603102, entropy = 4.677681635496143, freq = 0.0004053029076603, marginal prob = 0.9999999999999749
# 存|orthographic representation --> prob = 7.366654200042347e-05, entropy = 4.677681635496143, freq = 7.366654200042163e-05, marginal prob = 0.9999999999999749
# 季|orthographic representation --> prob = 8.275211866728556e-05, entropy = 4.6749870015126005, freq = 8.270370142798264e-05, marginal prob = 0.9994149123903693
# 孤|orthographic representation --> prob = 8.653764785179859e-06, entropy = 4.677681635496143, freq = 8.653764785179642e-06, marginal prob = 0.9999999999999749
# 学|orthographic representation --> prob = 0.0006714352472958717, entropy = 4.675075362627251, freq = 0.0006709406241674, marginal prob = 0.9992633345799707
# 孩|orthographic representation --> prob = 8.653764785179859e-06, entropy = 4.677681635496143, freq = 8.653764785179642e-06, marginal prob = 0.9999999999999749
# 它|orthographic representation --> prob = 0.002875459817860372, entropy = 4.677681635496143, freq = 0.0028754598178603, marginal prob = 0.9999999999999749
# 安|orthographic representation --> prob = 0.0002278459589009057, entropy = 4.677681635496143, freq = 0.0002278459589009, marginal prob = 0.9999999999999749
# 完|orthographic representation --> prob = 0.0004337159705556651, entropy = 4.670973443554188, freq = 0.0004326882392589, marginal prob = 0.9976304047659383
# 官|orthographic representation --> prob = 0.0002505774071402714, entropy = 4.670322451958693, freq = 0.0002497542241798, marginal prob = 0.9967148556213984
# 定|orthographic representation --> prob = 0.00030673780621159994, entropy = 4.677259490108844, freq = 0.0003067157139051, marginal prob = 0.9999279765778704
# 实|orthographic representation --> prob = 0.00018570969960304734, entropy = 4.671106221232922, freq = 0.000185124841607, marginal prob = 0.9968506868661278
# 客|orthographic representation --> prob = 0.00010230947439440454, entropy = 4.668801611641876, freq = 0.000101873433547, marginal prob = 0.995738020843274
# 宣|orthographic representation --> prob = 3.986589782817534e-05, entropy = 4.667617702386036, freq = 3.970873081807114e-05, marginal prob = 0.9960576076630305
# 家|orthographic representation --> prob = 0.0011969805773247306, entropy = 4.676600220507523, freq = 0.0011967389908618, marginal prob = 0.9997981701060927
# 容|orthographic representation --> prob = 4.3405521504856025e-05, entropy = 4.671106221232922, freq = 4.326882392589821e-05, marginal prob = 0.9968506868661278
# 寄|orthographic representation --> prob = 7.038030220858303e-05, entropy = 4.677681635496143, freq = 7.038030220858127e-05, marginal prob = 0.9999999999999749
# 密|orthographic representation --> prob = 5.586607646128769e-05, entropy = 4.677681635496143, freq = 5.586607646128629e-05, marginal prob = 0.9999999999999749
# 寒|orthographic representation --> prob = 7.886975500417086e-06, entropy = 4.677681635496143, freq = 7.886975500416888e-06, marginal prob = 0.9999999999999749
# 察|orthographic representation --> prob = 2.0785466683390867e-05, entropy = 4.677681635496143, freq = 2.0785466683390346e-05, marginal prob = 0.9999999999999749
# 对|orthographic representation --> prob = 0.01169395931333081, entropy = 4.677444847157029, freq = 0.0116935365926319, marginal prob = 0.9999638513622646
# 寻|orthographic representation --> prob = 2.9321295131252563e-05, entropy = 4.6746091713960185, freq = 2.9302304810576632e-05, marginal prob = 0.9993523369076664
# 封|orthographic representation --> prob = 0.00013117573835760328, entropy = 4.677681635496143, freq = 0.0001311757383576, marginal prob = 0.9999999999999749
# 将|orthographic representation --> prob = 0.005340139661740733, entropy = 4.677681635496143, freq = 0.0053401396617406, marginal prob = 0.9999999999999749
# 尊|orthographic representation --> prob = 2.6154596081852098e-05, entropy = 4.67731224645964, freq = 2.615299167672961e-05, marginal prob = 0.9999386568571939
# 小|orthographic representation --> prob = 0.0021251017320567532, entropy = 4.677681635496143, freq = 0.0021251017320567, marginal prob = 0.9999999999999749
# 少|orthographic representation --> prob = 0.0004545965045379114, entropy = 4.677681635496143, freq = 0.0004545965045379, marginal prob = 0.9999999999999749
# 尔|orthographic representation --> prob = 0.00024975422417980626, entropy = 4.677681635496143, freq = 0.0002497542241798, marginal prob = 0.9999999999999749
# 尘|orthographic representation --> prob = 1.0652893991882801e-05, entropy = 4.677681635496143, freq = 1.0652893991882534e-05, marginal prob = 0.9999999999999749
# 尚|orthographic representation --> prob = 0.00011419683276640286, entropy = 4.677681635496143, freq = 0.0001141968327664, marginal prob = 0.9999999999999749
# 尝|orthographic representation --> prob = 2.2264274589719068e-05, entropy = 4.677681635496143, freq = 2.226427458971851e-05, marginal prob = 0.9999999999999749
# 尤|orthographic representation --> prob = 4.7650476981686556e-05, entropy = 4.677681635496143, freq = 4.765047698168536e-05, marginal prob = 0.9999999999999749
# ...
# 达|orthographic representation --> prob = 0.0009064544759159228, entropy = 4.677681635496143, freq = 0.0009064544759159, marginal prob = 0.9999999999999749
# 迅|orthographic representation --> prob = 7.202342210450324e-06, entropy = 4.677681635496143, freq = 7.202342210450144e-06, marginal prob = 0.9999999999999749
# 过|orthographic representation --> prob = 0.0034505517814323867, entropy = 4.677681635496143, freq = 0.0034505517814323, marginal prob = 0.9999999999999749
# 迎|orthographic representation --> prob = 3.450551781432475e-05, entropy = 4.677681635496143, freq = 3.4505517814323886e-05, marginal prob = 0.9999999999999749
# 近|orthographic representation --> prob = 0.00043268823925891084, entropy = 4.677681635496143, freq = 0.0004326882392589, marginal prob = 0.9999999999999749
# 还|orthographic representation --> prob = 0.006572479583680865, entropy = 4.677681635496143, freq = 0.0065724795836807, marginal prob = 0.9999999999999749
# 这|orthographic representation --> prob = 0.01311757383576313, entropy = 4.677681635496143, freq = 0.0131175738357628, marginal prob = 0.9999999999999749
# 进|orthographic representation --> prob = 0.0008462067463988213, entropy = 4.677681635496143, freq = 0.0008462067463988, marginal prob = 0.9999999999999749
# 远|orthographic representation --> prob = 0.00036148637710240903, entropy = 4.677681635496143, freq = 0.0003614863771024, marginal prob = 0.9999999999999749
# 连|orthographic representation --> prob = 0.0007366654200042184, entropy = 4.677681635496143, freq = 0.0007366654200042, marginal prob = 0.9999999999999749
# 迟|orthographic representation --> prob = 5.586607646128769e-05, entropy = 4.677681635496143, freq = 5.586607646128629e-05, marginal prob = 0.9999999999999749
# 迹|orthographic representation --> prob = 2.174395328934433e-05, entropy = 4.677681635496143, freq = 2.1743953289343784e-05, marginal prob = 0.9999999999999749
# 送|orthographic representation --> prob = 0.0006134314278102154, entropy = 4.677681635496143, freq = 0.0006134314278102, marginal prob = 0.9999999999999749
# 适|orthographic representation --> prob = 2.174395328934433e-05, entropy = 4.677681635496143, freq = 2.1743953289343784e-05, marginal prob = 0.9999999999999749
# 逃|orthographic representation --> prob = 0.00011145829960650279, entropy = 4.677681635496143, freq = 0.0001114582996065, marginal prob = 0.9999999999999749
# 透|orthographic representation --> prob = 5.234927814415659e-05, entropy = 4.674851187089252, freq = 5.230598335345923e-05, marginal prob = 0.9991729629856951
# 逐|orthographic representation --> prob = 1.196738990861898e-05, entropy = 4.677681635496143, freq = 1.196738990861868e-05, marginal prob = 0.9999999999999749
# 递|orthographic representation --> prob = 1.8950649466279943e-05, entropy = 4.677681635496143, freq = 1.895064946627947e-05, marginal prob = 0.9999999999999749
# 通|orthographic representation --> prob = 0.00018101704186720456, entropy = 4.677681635496143, freq = 0.0001810170418672, marginal prob = 0.9999999999999749
# 速|orthographic representation --> prob = 3.861331755412532e-05, entropy = 4.677681635496143, freq = 3.861331755412435e-05, marginal prob = 0.9999999999999749
# 造|orthographic representation --> prob = 0.00013418812483340336, entropy = 4.677681635496143, freq = 0.0001341881248334, marginal prob = 0.9999999999999749
# 道|orthographic representation --> prob = 0.0009942010716452398, entropy = 4.677064919500531, freq = 0.0009940875370317, marginal prob = 0.9998858031672085
# 遗|orthographic representation --> prob = 1.7690924212741103e-05, entropy = 4.677681635496143, freq = 1.769092421274066e-05, marginal prob = 0.9999999999999749
# 那|orthographic representation --> prob = 0.00279330382306437, entropy = 4.677681635496143, freq = 0.0027933038230643, marginal prob = 0.9999999999999749
# 邮|orthographic representation --> prob = 1.9388814771858673e-05, entropy = 4.677681635496143, freq = 1.9388814771858185e-05, marginal prob = 0.9999999999999749
# 郁|orthographic representation --> prob = 4.874589024563338e-06, entropy = 4.677681635496143, freq = 4.874589024563216e-06, marginal prob = 0.9999999999999749
# 部|orthographic representation --> prob = 0.00039708730818070997, entropy = 4.677681635496143, freq = 0.0003970873081807, marginal prob = 0.9999999999999749
# 都|orthographic representation --> prob = 0.010652893991882767, entropy = 4.677681635496143, freq = 0.0106528939918825, marginal prob = 0.9999999999999749
# 酒|orthographic representation --> prob = 0.00016129960311610404, entropy = 4.677681635496143, freq = 0.0001612996031161, marginal prob = 0.9999999999999749
# 酷|orthographic representation --> prob = 3.7791757606165205e-05, entropy = 4.677681635496143, freq = 3.779175760616426e-05, marginal prob = 0.9999999999999749
# 醒|orthographic representation --> prob = 6.87371823126628e-05, entropy = 4.677681635496143, freq = 6.873718231266108e-05, marginal prob = 0.9999999999999749
# 采|orthographic representation --> prob = 7.038030220858303e-05, entropy = 4.677681635496143, freq = 7.038030220858127e-05, marginal prob = 0.9999999999999749
# 释|orthographic representation --> prob = 3.149313133847101e-05, entropy = 4.677681635496143, freq = 3.1493131338470215e-05, marginal prob = 0.9999999999999749
# 里|orthographic representation --> prob = 0.0033683957866363847, entropy = 4.677681635496143, freq = 0.0033683957866363, marginal prob = 0.9999999999999749
# 重|orthographic representation --> prob = 0.0003555319568080065, entropy = 4.663790711870475, freq = 0.0003532707776228, marginal prob = 0.9936400114197679
# 量|orthographic representation --> prob = 0.00022785191791021835, entropy = 4.677501858993582, freq = 0.0002278459589009, marginal prob = 0.9999738470082982
# 金|orthographic representation --> prob = 0.00043268823925891084, entropy = 4.677681635496143, freq = 0.0004326882392589, marginal prob = 0.9999999999999749
# 钟|orthographic representation --> prob = 0.00011419683276640286, entropy = 4.677681635496143, freq = 0.0001141968327664, marginal prob = 0.9999999999999749
# 钻|orthographic representation --> prob = 4.7650476981686556e-05, entropy = 4.677681635496143, freq = 4.765047698168536e-05, marginal prob = 0.9999999999999749
# 错|orthographic representation --> prob = 0.0003697019765820093, entropy = 4.677681635496143, freq = 0.000369701976582, marginal prob = 0.9999999999999749
# 锥|orthographic representation --> prob = 6.134314278102179e-06, entropy = 4.677681635496143, freq = 6.1343142781020245e-06, marginal prob = 0.9999999999999749
# 长|orthographic representation --> prob = 0.0016129960311616405, entropy = 4.677681635496143, freq = 0.0016129960311616, marginal prob = 0.9999999999999749
# 门|orthographic representation --> prob = 0.0004436423718984111, entropy = 4.677681635496143, freq = 0.0004436423718984, marginal prob = 0.9999999999999749
# 闪|orthographic representation --> prob = 4.436423718984611e-05, entropy = 4.677681635496143, freq = 4.4364237189845e-05, marginal prob = 0.9999999999999749
# 问|orthographic representation --> prob = 0.0011693536592631293, entropy = 4.677681635496143, freq = 0.0011693536592631, marginal prob = 0.9999999999999749
# 间|orthographic representation --> prob = 0.0009283627411949233, entropy = 4.677681635496143, freq = 0.0009283627411949, marginal prob = 0.9999999999999749
# 闹|orthographic representation --> prob = 6.709406241674257e-05, entropy = 4.677681635496143, freq = 6.709406241674089e-05, marginal prob = 0.9999999999999749
# 队|orthographic representation --> prob = 0.0004545965045379114, entropy = 4.677681635496143, freq = 0.0004545965045379, marginal prob = 0.9999999999999749
# 附|orthographic representation --> prob = 6.271240936095531e-05, entropy = 4.677681635496143, freq = 6.271240936095374e-05, marginal prob = 0.9999999999999749
# 陈|orthographic representation --> prob = 0.000238526238224406, entropy = 4.677681635496143, freq = 0.0002385262382244, marginal prob = 0.9999999999999749
# 降|orthographic representation --> prob = 0.00010899361976270274, entropy = 4.677681635496143, freq = 0.0001089936197627, marginal prob = 0.9999999999999749
# 限|orthographic representation --> prob = 6.87371823126628e-05, entropy = 4.677681635496143, freq = 6.873718231266108e-05, marginal prob = 0.9999999999999749
# 险|orthographic representation --> prob = 5.093671677352702e-05, entropy = 4.677681635496143, freq = 5.093671677352574e-05, marginal prob = 0.9999999999999749
# 随|orthographic representation --> prob = 0.0002738533159866069, entropy = 4.677681635496143, freq = 0.0002738533159866, marginal prob = 0.9999999999999749
# 隙|orthographic representation --> prob = 4.436423718984611e-06, entropy = 4.677681635496143, freq = 4.4364237189845e-06, marginal prob = 0.9999999999999749
# 难|orthographic representation --> prob = 0.00042447263977931065, entropy = 4.677681635496143, freq = 0.0004244726397793, marginal prob = 0.9999999999999749
# 雅|orthographic representation --> prob = 4.7650476981686556e-05, entropy = 4.677681635496143, freq = 4.765047698168536e-05, marginal prob = 0.9999999999999749
# 集|orthographic representation --> prob = 0.0003067587254349219, entropy = 4.676857080515297, freq = 0.0003067157139051, marginal prob = 0.9998597871021896
# 雨|orthographic representation --> prob = 8.462067463989165e-05, entropy = 4.677681635496143, freq = 8.462067463988953e-05, marginal prob = 0.9999999999999749
# 雪|orthographic representation --> prob = 6.14441179777662e-05, entropy = 4.670706467974334, freq = 6.134314278102024e-05, marginal prob = 0.9983566336360706
# 零|orthographic representation --> prob = 0.000119673899086103, entropy = 4.677681635496143, freq = 0.0001196738990861, marginal prob = 0.9999999999999749
# 雷|orthographic representation --> prob = 6.894360209813847e-05, entropy = 4.667827992506326, freq = 6.873718231266108e-05, marginal prob = 0.9970059616962925
# 霍|orthographic representation --> prob = 3.3683957866364645e-05, entropy = 4.677681635496143, freq = 3.36839578663638e-05, marginal prob = 0.9999999999999749
# 霜|orthographic representation --> prob = 1.196738990861898e-05, entropy = 4.677681635496143, freq = 1.196738990861868e-05, marginal prob = 0.9999999999999749
# 青|orthographic representation --> prob = 8.08268584329842e-05, entropy = 4.675523758044838, freq = 8.078672821607576e-05, marginal prob = 0.9995035039380911
# 非|orthographic representation --> prob = 0.0006709406241674168, entropy = 4.677681635496143, freq = 0.0006709406241674, marginal prob = 0.9999999999999749
# 面|orthographic representation --> prob = 0.00035327152836074567, entropy = 4.677661693481723, freq = 0.0003532707776228, marginal prob = 0.9999978748982429
# 革|orthographic representation --> prob = 1.56999678370463e-05, entropy = 4.697875166456267, freq = 1.5061932379268363e-05, marginal prob = 0.959360715614181
# 顶|orthographic representation --> prob = 0.00010187343354700256, entropy = 4.677681635496143, freq = 0.000101873433547, marginal prob = 0.9999999999999749
# 项|orthographic representation --> prob = 0.00029302304810570735, entropy = 4.677681635496143, freq = 0.0002930230481057, marginal prob = 0.9999999999999749
# 顺|orthographic representation --> prob = 5.2305983353460544e-05, entropy = 4.677681635496143, freq = 5.230598335345923e-05, marginal prob = 0.9999999999999749
# 顿|orthographic representation --> prob = 9.064544759159916e-05, entropy = 4.677681635496143, freq = 9.064544759159688e-05, marginal prob = 0.9999999999999749
# 预|orthographic representation --> prob = 3.067157139051089e-05, entropy = 4.677681635496143, freq = 3.067157139051012e-05, marginal prob = 0.9999999999999749
# 频|orthographic representation --> prob = 1.752052676177347e-05, entropy = 4.669274943482189, freq = 1.728014423876061e-05, marginal prob = 0.9862799488690415
# 颗|orthographic representation --> prob = 5.340225799370935e-05, entropy = 4.677562963166634, freq = 5.340139661740602e-05, marginal prob = 0.9999838700396633
# 题|orthographic representation --> prob = 0.0001437729908930036, entropy = 4.677681635496143, freq = 0.000143772990893, marginal prob = 0.9999999999999749
# 颠|orthographic representation --> prob = 3.6975007379185325e-06, entropy = 4.676906107256749, freq = 3.697019765820417e-06, marginal prob = 0.9998699196748811
# 风|orthographic representation --> prob = 0.000238526238224406, entropy = 4.677681635496143, freq = 0.0002385262382244, marginal prob = 0.9999999999999749
# 食|orthographic representation --> prob = 7.53096618963437e-05, entropy = 4.677681635496143, freq = 7.530966189634182e-05, marginal prob = 0.9999999999999749
# 饭|orthographic representation --> prob = 0.00013720051130930344, entropy = 4.677681635496143, freq = 0.0001372005113093, marginal prob = 0.9999999999999749
# 饮|orthographic representation --> prob = 2.9302304810577367e-05, entropy = 4.677681635496143, freq = 2.9302304810576632e-05, marginal prob = 0.9999999999999749
# 饰|orthographic representation --> prob = 3.3683957866364645e-05, entropy = 4.677681635496143, freq = 3.36839578663638e-05, marginal prob = 0.9999999999999749
# 馆|orthographic representation --> prob = 0.00018950649466270474, entropy = 4.677681635496143, freq = 0.0001895064946627, marginal prob = 0.9999999999999749
# 香|orthographic representation --> prob = 8.462067463989165e-05, entropy = 4.677681635496143, freq = 8.462067463988953e-05, marginal prob = 0.9999999999999749
# 驯|orthographic representation --> prob = 1.8950649466279944e-06, entropy = 4.677681635496143, freq = 1.8950649466279468e-06, marginal prob = 0.9999999999999749
# 驾|orthographic representation --> prob = 2.3852623822441957e-05, entropy = 4.677681635496143, freq = 2.3852623822441357e-05, marginal prob = 0.9999999999999749
# 骨|orthographic representation --> prob = 3.6979382780629126e-05, entropy = 4.676291895655952, freq = 3.697019765820416e-05, marginal prob = 0.9997516150423751
# 骸|orthographic representation --> prob = 5.723534304122122e-06, entropy = 4.677681635496143, freq = 5.723534304121978e-06, marginal prob = 0.9999999999999749
# 骼|orthographic representation --> prob = 3.1493131338471e-07, entropy = 4.677681635496143, freq = 3.149313133847021e-07, marginal prob = 0.9999999999999749
# 高|orthographic representation --> prob = 0.001539792727843341, entropy = 4.675423745986965, freq = 0.0015390556358452, marginal prob = 0.9995213044036301
# 鱼|orthographic representation --> prob = 0.00017690924212740444, entropy = 4.677681635496143, freq = 0.0001769092421274, marginal prob = 0.9999999999999749
# 鹿|orthographic representation --> prob = 2.3863472073432677e-05, entropy = 4.675854148976946, freq = 2.3852623822441357e-05, marginal prob = 0.999545403495437
# 黄|orthographic representation --> prob = 0.00039708730818070997, entropy = 4.677681635496143, freq = 0.0003970873081807, marginal prob = 0.9999999999999749
# 黑|orthographic representation --> prob = 0.0004053029076603102, entropy = 4.677681635496143, freq = 0.0004053029076603, marginal prob = 0.9999999999999749
# 默|orthographic representation --> prob = 1.612996031161689e-05, entropy = 4.677681635496143, freq = 1.6129960311616486e-05, marginal prob = 0.9999999999999749
# 黝|orthographic representation --> prob = 1.98269800774374e-07, entropy = 4.677681635496143, freq = 1.98269800774369e-07, marginal prob = 0.9999999999999749
# 鼓|orthographic representation --> prob = 2.4975422417987444e-05, entropy = 4.677681635496143, freq = 2.4975422417986817e-05, marginal prob = 0.9999999999999749
# 齐|orthographic representation --> prob = 6.408167594088883e-05, entropy = 4.677681635496143, freq = 6.408167594088722e-05, marginal prob = 0.9999999999999749
# 齿|orthographic representation --> prob = 1.98269800774374e-05, entropy = 4.677681635496143, freq = 1.98269800774369e-05, marginal prob = 0.9999999999999749
# 龄|orthographic representation --> prob = 7.722663510825064e-06, entropy = 4.677681635496143, freq = 7.722663510824871e-06, marginal prob = 0.9999999999999749
# 龙|orthographic representation --> prob = 0.00019388814771850485, entropy = 4.677681635496143, freq = 0.0001938881477185, marginal prob = 0.9999999999999749
# Overall conditional entropy H(L|O) = 4.6773 nats
# Sum of frequencies (should be ~1.0) = 1.0000

# %% [markdown]
# #### Scale the SSIM score with an exp function and a temperature alph = 10.0.
# #### This result is the numbers reported in the paper

# %%
import os
import json
import numpy as np
import pandas as pd
from PIL import Image
from skimage.metrics import structural_similarity as ssim
from scipy.stats import entropy

# -----------------------------
# Configurations
# -----------------------------
visible = "whole"   # "upper" or "lower"
lang = "zh"         # "en" or "zh"
resize_shape = (128, 128)

# Similarity transformation parameters
sim_method = "exp"   # options: "exp", "power", "minmax", "raw"
alpha = 10.0         # strength for exp scaling
beta = 2.0           # strength for power scaling

if lang == "en":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/en/onestop/en_word_onestop_uniWords_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/EN"
elif lang == "zh":
    img_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/images"
    jsonl_file_path = f"/swdata/yin/Cui/EM/reveil/data/zh/zh-char/onestop/zh_char_onestop_uniqueChar_newFont/{visible}/img_dict_test.json"
    out_path = "/swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/ZH"

# -----------------------------
# Similarity transformation
# -----------------------------
def transform_similarity(sim, method="exp", alpha=2.0, beta=2.0):
    """
    Transform similarity into a likelihood.
    """
    if method == "exp":
        return np.exp(alpha * sim)
    elif method == "power":
        return np.power(max(sim, 1e-6), beta)
    elif method == "minmax":
        # clip and rescale to [0,1]
        sim = np.clip(sim, 0.0, 1.0)
        return np.power(sim, beta)
    else:  # "raw"
        return max(sim, 1e-6)

# -----------------------------
# Load dataset
# -----------------------------
with open(jsonl_file_path, 'r') as file:
    lines = file.readlines()
print("total lines:", len(lines))

data_list = [json.loads(line) for line in lines]

# Preload images to memory
image_cache = {}
for data in data_list:
    label = data["label"]
    img_file = os.path.join(img_path, data["image"])
    img_array = np.array(Image.open(img_file).convert("L").resize(resize_shape))
    image_cache[label] = (img_array, data["normal_freq"])

# -----------------------------
# Bayesian baseline computation
# -----------------------------
results = {}
overall_entropy = 0.0
rows = []

for target_label, (target_img, p_target_prior) in image_cache.items():
    likelihoods = []
    
    for comp_label, (comp_img, p_comp_prior) in image_cache.items():
        similarity = ssim(target_img, comp_img)
        p_likelihood = transform_similarity(similarity, method=sim_method, alpha=alpha, beta=beta)
        likelihoods.append((comp_label, p_comp_prior, p_likelihood))
    
    # Marginal likelihood
    Z = sum(p_prior * p_like for _, p_prior, p_like in likelihoods)
    
    # Posterior distribution
    posteriors = {}
    for comp_label, p_prior, p_like in likelihoods:
        p_post = (p_prior * p_like) / Z if Z > 0 else 0
        posteriors[comp_label] = p_post
    
    # Entropy of posterior
    posterior_probs = list(posteriors.values())
    ent_cond = entropy(posterior_probs)  # in nats
    
    results[target_label] = {
        "posterior_entropy": ent_cond,
        "prior": p_target_prior,
        "posterior_target": posteriors[target_label],
        "marginal_likelihood": Z
    }
    
    overall_entropy += p_target_prior * ent_cond
    
    rows.append({
        "target": target_label,
        "prior": p_target_prior,
        "posterior_target": posteriors[target_label],
        "entropy": ent_cond,
        "marginal_likelihood": Z
    })

# -----------------------------
# Summarize results
# -----------------------------
print(f"Overall conditional entropy H(W|O) = {overall_entropy:.4f} nats")

df = pd.DataFrame(rows)
os.makedirs(out_path, exist_ok=True)
out_csv = f"{out_path}/bayesian_baseline_{lang}_{visible}_{sim_method}_{alpha}.csv"
df.to_csv(out_csv, index=False)
print(f"Results saved to {out_csv}")
# Out:
# total lines: 936
# Overall conditional entropy H(W|O) = 0.7324 nats
# Results saved to /swdata/yin/Cui/EM/reveil/precomputed/baseline_onestop/ZH/bayesian_baseline_zh_whole_exp_10.0.csv
